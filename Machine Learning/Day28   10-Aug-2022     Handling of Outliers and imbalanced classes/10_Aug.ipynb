# %%
# Dimensionality Reduction( reduce something) ( reduce the size of the features)
# Meaning of Dimensionality( Features ) ( 150 )

# %%
# Feature(columns) Extraction ( 40 )

# %%
# Imbalance class ( pass(1000), fail(20))

# %%
# Anamoly(defaulter) detection

# %%
import pandas as pd
import numpy as np
df = pd.read_csv('/content/creditcard.csv')
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
#         V26       V27       V28  Amount  Class
# 0 -0.189115  0.133558 -0.021053  149.62    0.0
# 1  0.125895 -0.008983  0.014724    2.69    0.0
# 2 -0.139097 -0.055353 -0.059752  378.66    0.0
# 3 -0.221929  0.062723  0.061458  123.50    0.0
# 4  0.502292  0.219422  0.215153   69.99    0.0
#
# [5 rows x 31 columns]

# %%
df.describe()
# Out:
#               Time           V1           V2           V3           V4  \
# count  1361.000000  1361.000000  1361.000000  1361.000000  1361.000000
# mean    514.825863    -0.198982     0.238001     0.874082     0.255328
# std     309.283427     1.316233     1.126812     0.998001     1.238464
# min       0.000000    -6.169664   -12.114213    -5.694973    -4.657545
# 25%     250.000000    -0.946412    -0.191528     0.306923    -0.435770
# 50%     513.000000    -0.378602     0.284169     0.880670     0.326411
# 75%     770.000000     1.115420     0.874648     1.513242     1.056448
# max    1056.000000     1.685314     6.118940     4.017561     4.861129
#
#                 V5           V6           V7           V8           V9  ...  \
# count  1361.000000  1361.000000  1361.000000  1361.000000  1361.000000  ...
# mean     -0.028828     0.100497     0.118191    -0.062811    -0.006052  ...
# std       1.052003     1.182563     0.831322     0.894384     0.904311  ...
# min      -6.631951    -3.498447    -4.925568   -12.258158    -3.110515  ...
# 25%      -0.538265    -0.649977    -0.294561    -0.175546    -0.492432  ...
# 50%      -0.124122    -0.141452     0.107001     0.025718    -0.078400  ...
# 75%       0.421537     0.456425     0.579042     0.247130     0.423690  ...
# max       7.672544     5.122103     6.359749     3.877662     6.450992  ...
#
#                V21          V22          V23          V24          V25  \
# count  1361.000000  1361.000000  1361.000000  1361.000000  1361.000000
# mean     -0.013770    -0.122334    -0.044944    -0.003651     0.113419
# std       0.589638     0.598147     0.364334     0.614079     0.419954
# min      -4.134608    -2.776923    -4.020300    -1.867208    -1.577384
# 25%      -0.219791    -0.540069    -0.182787    -0.370398    -0.157577
# 50%      -0.080364    -0.111163    -0.055459     0.091474     0.145658
# 75%       0.082280     0.281378     0.063974     0.421234     0.412081
# max       5.273420     1.957759     4.095021     1.215279     1.206820
#
#                V26          V27          V28       Amount       Class
# count  1361.000000  1361.000000  1361.000000  1361.000000  1361.00000
# mean      0.034426     0.014038    -0.010578    66.225356     0.00147
# std       0.458609     0.335347     0.256108   177.871265     0.03832
# min      -1.243924    -3.525281    -2.735623     0.000000     0.00000
# 25%      -0.294853    -0.054094    -0.019047     5.000000     0.00000
# 50%       0.019571     0.020377     0.020990    15.380000     0.00000
# 75%       0.274310     0.114264     0.085367    59.880000     0.00000
# max       3.087444     2.490503     1.575380  3828.040000     1.00000
#
# [8 rows x 31 columns]

# %%
df.isnull().sum().max()
# Out:
# 283256

# %%
df.columns
# Out:
# Index(['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10',
#        'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20',
#        'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount',
#        'Class'],
#       dtype='object')

# %%
df['Class'].value_counts()
# Out:
# 0.0    1359
# 1.0       2
# Name: Class, dtype: int64

# %%
print('No Fraud', round(df['Class'].value_counts()[0]/len(df), 2))
# Out:
# No Fraud 0.48

# %%
print('No Fraud', df['Class'].value_counts()[1]/len(df)*100)
# Out:
# No Fraud 0.000702698714412702

# %%
import seaborn as sns
sns.countplot('Class', data = df)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.distplot(df['Amount'].values)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
from sklearn.preprocessing import StandardScaler, RobustScaler
std_scaler = StandardScaler()
rob_scaler = RobustScaler()

# %%
df['scaled_amount'] = rob_scaler.fit_transform(df['Amount'].values.reshape(-1,1))
df['scaled_time'] = rob_scaler.fit_transform(df['Time'].values.reshape(-1, 1))

# %%
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V23       V24       V25       V26       V27  \
# 0  0.098698  0.363787  ... -0.110474  0.066928  0.128539 -0.189115  0.133558
# 1  0.085102 -0.255425  ...  0.101288 -0.339846  0.167170  0.125895 -0.008983
# 2  0.247676 -1.514654  ...  0.909412 -0.689281 -0.327642 -0.139097 -0.055353
# 3  0.377436 -1.387024  ... -0.190321 -1.175575  0.647376 -0.221929  0.062723
# 4 -0.270533  0.817739  ... -0.137458  0.141267 -0.206010  0.502292  0.219422
#
#         V28  Amount  Class  scaled_amount  scaled_time
# 0 -0.021053  149.62    0.0       2.446064    -0.986538
# 1  0.014724    2.69    0.0      -0.231232    -0.986538
# 2 -0.059752  378.66    0.0       6.619534    -0.984615
# 3  0.061458  123.50    0.0       1.970117    -0.984615
# 4  0.215153   69.99    0.0       0.995080    -0.982692
#
# [5 rows x 33 columns]

# %%
scaled_amount = df['scaled_amount']
scaled_time  = df['scaled_time']
df.drop(['scaled_amount', 'scaled_time'], axis = 1, inplace = True)

# %%
df.insert(0, 'scaled_amount', scaled_amount)
df.insert(1, 'scaled_time', scaled_time)
df.head()
# Out:
#    scaled_amount  scaled_time  Time        V1        V2        V3        V4  \
# 0       2.446064    -0.986538   0.0 -1.359807 -0.072781  2.536347  1.378155
# 1      -0.231232    -0.986538   0.0  1.191857  0.266151  0.166480  0.448154
# 2       6.619534    -0.984615   1.0 -1.358354 -1.340163  1.773209  0.379780
# 3       1.970117    -0.984615   1.0 -0.966272 -0.185226  1.792993 -0.863291
# 4       0.995080    -0.982692   2.0 -1.158233  0.877737  1.548718  0.403034
#
#          V5        V6        V7  ...       V21       V22       V23       V24  \
# 0 -0.338321  0.462388  0.239599  ... -0.018307  0.277838 -0.110474  0.066928
# 1  0.060018 -0.082361 -0.078803  ... -0.225775 -0.638672  0.101288 -0.339846
# 2 -0.503198  1.800499  0.791461  ...  0.247998  0.771679  0.909412 -0.689281
# 3 -0.010309  1.247203  0.237609  ... -0.108300  0.005274 -0.190321 -1.175575
# 4 -0.407193  0.095921  0.592941  ... -0.009431  0.798278 -0.137458  0.141267
#
#         V25       V26       V27       V28  Amount  Class
# 0  0.128539 -0.189115  0.133558 -0.021053  149.62    0.0
# 1  0.167170  0.125895 -0.008983  0.014724    2.69    0.0
# 2 -0.327642 -0.139097 -0.055353 -0.059752  378.66    0.0
# 3  0.647376 -0.221929  0.062723  0.061458  123.50    0.0
# 4 -0.206010  0.502292  0.219422  0.215153   69.99    0.0
#
# [5 rows x 33 columns]

# %%
df.drop(['Time', 'Amount'], axis = 1, inplace = True)

# %%
df.head()
# Out:
#    scaled_amount  scaled_time        V1        V2        V3        V4  \
# 0       2.446064    -0.986538 -1.359807 -0.072781  2.536347  1.378155
# 1      -0.231232    -0.986538  1.191857  0.266151  0.166480  0.448154
# 2       6.619534    -0.984615 -1.358354 -1.340163  1.773209  0.379780
# 3       1.970117    -0.984615 -0.966272 -0.185226  1.792993 -0.863291
# 4       0.995080    -0.982692 -1.158233  0.877737  1.548718  0.403034
#
#          V5        V6        V7        V8  ...       V20       V21       V22  \
# 0 -0.338321  0.462388  0.239599  0.098698  ...  0.251412 -0.018307  0.277838
# 1  0.060018 -0.082361 -0.078803  0.085102  ... -0.069083 -0.225775 -0.638672
# 2 -0.503198  1.800499  0.791461  0.247676  ...  0.524980  0.247998  0.771679
# 3 -0.010309  1.247203  0.237609  0.377436  ... -0.208038 -0.108300  0.005274
# 4 -0.407193  0.095921  0.592941 -0.270533  ...  0.408542 -0.009431  0.798278
#
#         V23       V24       V25       V26       V27       V28  Class
# 0 -0.110474  0.066928  0.128539 -0.189115  0.133558 -0.021053    0.0
# 1  0.101288 -0.339846  0.167170  0.125895 -0.008983  0.014724    0.0
# 2  0.909412 -0.689281 -0.327642 -0.139097 -0.055353 -0.059752    0.0
# 3 -0.190321 -1.175575  0.647376 -0.221929  0.062723  0.061458    0.0
# 4 -0.137458  0.141267 -0.206010  0.502292  0.219422  0.215153    0.0
#
# [5 rows x 31 columns]

# %%
from sklearn.model_selection import train_test_split
from sklearn.model_selection import StratifiedShuffleSplit
X = df.drop('Class', axis = 1)
y = df['Class']

# %%
from sklearn.model_selection import KFold, StratifiedKFold
sf = StratifiedKFold(n_splits = 5, random_state = None, shuffle = True)

# %%
for Train, test in sf.split(X, y):
  print('Train: ', Train, 'Test: ', test)
  Ori_X_train, Ori_X_test = X.iloc[Train], X.iloc[test]
  Ori_y_train, Ori_y_test = y.iloc[Train], y.iloc[test]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-45-a9bdf6d4e4f3> in <module>()
# ----> 1 for Train, test in sf.split(X, y):
#       2   print('Train: ', Train, 'Test: ', test)
#       3   Ori_X_train, Ori_X_test = X.iloc[Train], X.iloc[test]
#       4   Ori_y_train, Ori_y_test = y.iloc[Train], y.iloc[test]
#
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_split.py in split(self, X, y, groups)
#     745         to an integer.
#     746         """
# --> 747         y = check_array(y, ensure_2d=False, dtype=None)
#     748         return super().split(X, y, groups)
#     749
#
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     798
#     799         if force_all_finite:
# --> 800             _assert_all_finite(array, allow_nan=force_all_finite == "allow-nan")
#     801
#     802     if ensure_min_samples > 0:
#
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py in _assert_all_finite(X, allow_nan, msg_dtype)
#     114             raise ValueError(
#     115                 msg_err.format(
# --> 116                     type_err, msg_dtype if msg_dtype is not None else X.dtype
#     117                 )
#     118             )
#
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').

# %%
df = df.sample(frac = 1)

# %%
fraud_df = df.loc[df['Class']==1]
non_fraud_df = df.loc[df['Class']==0]

# %%
normal_dis = pd.concat([fraud_df, non_fraud_df])

# %%
new_df = normal_dis.sample(frac = 1, random_state = 32)

# %%
new_df['Class'].value_counts()/len(new_df)
sns.countplot('Class', data = new_df)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
from sklearn.metrics import accuracy_score
X_train, X_test, Y_train, Y_test = train_test_split(X, y, test_size = 0.25, random_state = 0)

# %%
from sklearn.dummy import DummyClassifier
dummy = DummyClassifier(strategy = 'most_frequent').fit(X_train, Y_train)
dummy_pred = dummy.predict(X_test)
print(accuracy_score(Y_test, dummy_pred))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-58-f0609b501168> in <module>()
#       2 dummy = DummyClassifier(strategy = 'most_frequent').fit(X_train, Y_train)
#       3 dummy_pred = dummy.predict(X_test)
# ----> 4 print(accuracy_score(Y_test, dummy_pred))
#
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py in accuracy_score(y_true, y_pred, normalize, sample_weight)
#     209
#     210     # Compute accuracy for each possible representation
# --> 211     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#     212     check_consistent_length(y_true, y_pred, sample_weight)
#     213     if y_type.startswith("multilabel"):
#
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py in _check_targets(y_true, y_pred)
#      83     """
#      84     check_consistent_length(y_true, y_pred)
# ---> 85     type_true = type_of_target(y_true)
#      86     type_pred = type_of_target(y_pred)
#      87
#
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/multiclass.py in type_of_target(y)
#     322     if y.dtype.kind == "f" and np.any(y != y.astype(int)):
#     323         # [.1, .2, 3] or [[.1, .2, 3]] or [[1., .2]] and not [1., 2., 3.]
# --> 324         _assert_all_finite(y)
#     325         return "continuous" + suffix
#     326
#
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py in _assert_all_finite(X, allow_nan, msg_dtype)
#     114             raise ValueError(
#     115                 msg_err.format(
# --> 116                     type_err, msg_dtype if msg_dtype is not None else X.dtype
#     117                 )
#     118             )
#
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').
