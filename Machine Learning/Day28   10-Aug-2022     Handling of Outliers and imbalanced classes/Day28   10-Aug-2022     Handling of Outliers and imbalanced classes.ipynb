# %% [markdown]
# Sub-Topics
#
# 1. Anomaly Detection
# 2. Application in Industry
# 3. Dealing with Imbalanced Classes

# %%
# Feature(column) Extraction - which will extract column which is important from the thousands of columns.

# %%
# Robust Model basically means good model - which does not have any out lyer and overfitting issue.

# %%
# Dimensionality Reduction( reduce something) ( reduce the size of the features)
# Meaning of Dimensionality( Features ) ( 150 )

# %%
# Feature(columns) Extraction ( 40 )

# %%
# Imbalance class ( pass(1000), fail(20))

# %%
# Anamoly(defaulter) detection

# %%
import pandas as pd
import numpy as np
df = pd.read_csv(r"D:\Data Science\MACHINE LEARNING\creditcard.csv")
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
df.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  3.918649e-15  5.682686e-16 -8.761736e-15  2.811118e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean  -1.552103e-15  2.040130e-15 -1.698953e-15 -1.893285e-16 -3.147640e-15
# ...

# %%
df.isnull().sum().max()
# Out:
# 0

# %%
df.columns
# Out:
# Index(['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10',
#        'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20',
#        'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount',
#        'Class'],
#       dtype='object')

# %%
df['Class'].value_counts()
# Out:
# 0    284315
# 1       492
# Name: Class, dtype: int64

# %%
print('No Fraud',(df['Class'].value_counts()[0]/len(df))*100,"%") # my solution
# Out:
# No Fraud 99.82725143693798 %

# %%
print('No Fraud', round(df['Class'].value_counts()[0]/len(df), 2)) # not sure about this output
# Out:
# No Fraud 1.0

# %%
print('Fraud', df['Class'].value_counts()[1]/len(df)*100,'%')
# Out:
# Fraud 0.1727485630620034 %

# %%
import seaborn as sns
sns.countplot('Class', data = df)
# Out:
# <AxesSubplot:xlabel='Class', ylabel='count'>

# %%
import warnings  # it will ignore warnings
warnings.filterwarnings('ignore')

# %%
sns.distplot(df['Amount'].values)
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
from sklearn.preprocessing import StandardScaler, RobustScaler
std_scaler = StandardScaler()
rob_scaler = RobustScaler()

# %%
df['scaled_amount'] = rob_scaler.fit_transform(df['Amount'].values.reshape(-1,1))
df['scaled_time'] = rob_scaler.fit_transform(df['Time'].values.reshape(-1, 1))

# %%
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V23       V24       V25       V26       V27  \
# 0  0.098698  0.363787  ... -0.110474  0.066928  0.128539 -0.189115  0.133558
# 1  0.085102 -0.255425  ...  0.101288 -0.339846  0.167170  0.125895 -0.008983
# 2  0.247676 -1.514654  ...  0.909412 -0.689281 -0.327642 -0.139097 -0.055353
# 3  0.377436 -1.387024  ... -0.190321 -1.175575  0.647376 -0.221929  0.062723
# 4 -0.270533  0.817739  ... -0.137458  0.141267 -0.206010  0.502292  0.219422
#
# ...

# %%
scaled_amount = df['scaled_amount']
scaled_time  = df['scaled_time']
df.drop(['scaled_amount', 'scaled_time'], axis = 1, inplace = True)

# %%
df.insert(0, 'scaled_amount', scaled_amount)
df.insert(1, 'scaled_time', scaled_time)
df.head()
# Out:
#    scaled_amount  scaled_time  Time        V1        V2        V3        V4  \
# 0       1.783274    -0.994983   0.0 -1.359807 -0.072781  2.536347  1.378155
# 1      -0.269825    -0.994983   0.0  1.191857  0.266151  0.166480  0.448154
# 2       4.983721    -0.994972   1.0 -1.358354 -1.340163  1.773209  0.379780
# 3       1.418291    -0.994972   1.0 -0.966272 -0.185226  1.792993 -0.863291
# 4       0.670579    -0.994960   2.0 -1.158233  0.877737  1.548718  0.403034
#
#          V5        V6        V7  ...       V21       V22       V23       V24  \
# 0 -0.338321  0.462388  0.239599  ... -0.018307  0.277838 -0.110474  0.066928
# 1  0.060018 -0.082361 -0.078803  ... -0.225775 -0.638672  0.101288 -0.339846
# 2 -0.503198  1.800499  0.791461  ...  0.247998  0.771679  0.909412 -0.689281
# 3 -0.010309  1.247203  0.237609  ... -0.108300  0.005274 -0.190321 -1.175575
# 4 -0.407193  0.095921  0.592941  ... -0.009431  0.798278 -0.137458  0.141267
#
# ...

# %%
df.drop(['Time', 'Amount'], axis = 1, inplace = True)

# %%
df.head()
# Out:
#    scaled_amount  scaled_time        V1        V2        V3        V4  \
# 0       1.783274    -0.994983 -1.359807 -0.072781  2.536347  1.378155
# 1      -0.269825    -0.994983  1.191857  0.266151  0.166480  0.448154
# 2       4.983721    -0.994972 -1.358354 -1.340163  1.773209  0.379780
# 3       1.418291    -0.994972 -0.966272 -0.185226  1.792993 -0.863291
# 4       0.670579    -0.994960 -1.158233  0.877737  1.548718  0.403034
#
#          V5        V6        V7        V8  ...       V20       V21       V22  \
# 0 -0.338321  0.462388  0.239599  0.098698  ...  0.251412 -0.018307  0.277838
# 1  0.060018 -0.082361 -0.078803  0.085102  ... -0.069083 -0.225775 -0.638672
# 2 -0.503198  1.800499  0.791461  0.247676  ...  0.524980  0.247998  0.771679
# 3 -0.010309  1.247203  0.237609  0.377436  ... -0.208038 -0.108300  0.005274
# 4 -0.407193  0.095921  0.592941 -0.270533  ...  0.408542 -0.009431  0.798278
#
#         V23       V24       V25       V26       V27       V28  Class
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.model_selection import StratifiedShuffleSplit
X = df.drop('Class', axis=1)
y = df['Class']

# %%
from sklearn.model_selection import KFold, StratifiedKFold
sf = StratifiedKFold(n_splits=5, random_state=None, shuffle=True)

# %%
for Train, test in sf.split(X, y):
  print('Train: ', Train, 'Test: ', test)
  Ori_X_train, Ori_X_test = X.iloc[Train], X.iloc[test]
  Ori_y_train, Ori_y_test = y.iloc[Train], y.iloc[test]
# Out:
# Train:  [     0      1      2 ... 284803 284804 284806] Test:  [     3      9     12 ... 284786 284793 284805]
# Train:  [     0      1      3 ... 284802 284805 284806] Test:  [     2      6     13 ... 284801 284803 284804]
# Train:  [     1      2      3 ... 284804 284805 284806] Test:  [     0      4      5 ... 284792 284798 284802]
# Train:  [     0      2      3 ... 284803 284804 284805] Test:  [     1      7     28 ... 284787 284799 284806]
# Train:  [     0      1      2 ... 284804 284805 284806] Test:  [    11     19     20 ... 284788 284790 284800]

# %%
df = df.sample(frac = 1)

# %%
fraud_df = df.loc[df['Class']==1]
non_fraud_df = df.loc[df['Class']==0]

# %%
normal_dis = pd.concat([fraud_df, non_fraud_df])

# %%
new_df = normal_dis.sample(frac = 1, random_state = 32)

# %%
new_df['Class'].value_counts()/len(new_df)
sns.countplot('Class', data = new_df)
# Out:
# <AxesSubplot:xlabel='Class', ylabel='count'>

# %%
from sklearn.metrics import accuracy_score
X_train, X_test, Y_train, Y_test = train_test_split(X, y, test_size = 0.25, random_state = 0)

# %%
from sklearn.dummy import DummyClassifier
dummy = DummyClassifier(strategy = 'most_frequent').fit(X_train, Y_train)
dummy_pred = dummy.predict(X_test)
print(accuracy_score(Y_test, dummy_pred))
# Out:
# 0.9983146540827504
