# %% [markdown]
# # Decision Tree

# %% [markdown]
# A decision tree is a graphical representation of all the possible solutions to a decision based on certain conditions.

# %%
from IPython.display import Image
Image(filename='C:\\Users\\uttam.grade\\downloads\d1.png')

# %%
from IPython.display import Image
Image(filename='C:\\Users\\uttam.grade\\downloads\d3.png')

# %% [markdown]
# A Decision Tree algorithm is one of the most popular machine learning algorithms. It uses a tree like structure and their possible combinations to solve a particular problem. It belongs to the class of supervised learning algorithms where it can be used for both classification and regression purposes.
#
# A decision tree is a structure that includes a root node, branches, and leaf nodes. Each internal node denotes a test on an attribute, each branch denotes the outcome of a test, and each leaf node holds a class label. The topmost node in the tree is the root node.
#
# We make some assumptions while implementing the Decision-Tree algorithm. These are listed below:-
#
# At the beginning, the whole training set is considered as the root.
# Feature values need to be categorical. If the values are continuous then they are discretized prior to building the model.
# Records are distributed recursively on the basis of attribute values.
# Order to placing attributes as root or internal node of the tree is done by using some statistical approach.

# %%
from IPython.display import Image
Image(filename='C: (351).png')

# %% [markdown]
# Decision Tree algorithm terminology
#
# In a Decision Tree algorithm, there is a tree like structure in which each internal node represents a test on an attribute, each branch represents the outcome of the test, and each leaf node represents a class label. The paths from the root node to leaf node represent classification rules.
#
# We can see that there is some terminology involved in Decision Tree algorithm. The terms involved in Decision Tree algorithm are as follows:-

# %%
from IPython.display import Image
Image(filename='C:\\\\Screenshot (352).png')

# %% [markdown]
# Root Node
#
# It represents the entire population or sample. This further gets divided into two or more homogeneous sets.
#
# Splitting
#
# It is a process of dividing a node into two or more sub-nodes.
#
# Decision Node
#
# When a sub-node splits into further sub-nodes, then it is called a decision node.
#
# Leaf/Terminal Node
#
# Nodes that do not split are called Leaf or Terminal nodes.
#
# Pruning
#
# When we remove sub-nodes of a decision node, this process is called pruning. It is the opposite process of splitting.
#
# Branch/Sub-Tree
#
# A sub-section of an entire tree is called a branch or sub-tree.
#
# Parent and Child Node
#
# A node, which is divided into sub-nodes is called the parent node of sub-nodes where sub-nodes are the children of a parent node.

# %%
from IPython.display import Image
Image(filename='C:\\Users\\uttam.grade\\downloads\d4.png')

# %%
from IPython.display import Image
Image(filename='Chots\\Screenshot (353).png')

# %% [markdown]
# The Decision Tree algorithm intuition is as follows:-
#
# For each attribute in the dataset, the Decision-Tree algorithm forms a node. The most important attribute is placed at the root node.
#
# For evaluating the task in hand, we start at the root node and we work our way down the tree by following the corresponding node that meets our condition or decision.
#
# This process continues until a leaf node is reached. It contains the prediction or the outcome of the Decision Tree.

# %% [markdown]
# The primary challenge in the Decision Tree implementation is to identify the attributes which we consider as the root node and each level. This process is known as the attributes selection. There are different attributes selection measure to identify the attribute which can be considered as the root node at each level.
#
# There are 2 popular attribute selection measures. They are as follows:-
#
# Information gain
#
# Gini index
#
# While using Information gain as a criterion, we assume attributes to be categorical and for Gini index attributes are assumed to be continuous. These attribute selection measures are described below.

# %% [markdown]
# Information gain
#
# By using information gain as a criterion, we try to estimate the information contained by each attribute. To understand the concept of Information Gain, we need to know another concept called Entropy.

# %%
#Entropy will tell us the purity of split
# IG will tell us the Quality of a split

# %% [markdown]
# Entropy
#
# Entropy measures the impurity in the given dataset

# %%
from IPython.display import Image
Image(filename='C:\\Users\\uttam.grade\\downloads\d7.png')

# %%
from IPython.display import Image
Image(filename='C:\\Users\\uttam.grade\\downloads\d9.png')

# %%
from IPython.display import Image
Image(filename='C:\\Users\\uttam.grade\\downloads\d8.png')

# %%
from IPython.display import Image
Image(filename='C:\\Users\\uttam.grade\\downloads\d10.png')

# %% [markdown]
# # Difference B/w Gini and Entropy

# %% [markdown]
# The Gini Index and the Entropy have two main differences: Gini Index has values inside the interval [0, 0.5] whereas the interval of the Entropy is [0, 1]

# %% [markdown]
# # Overfitting in Decision Tree algorithm

# %% [markdown]
# Overfitting is a practical problem while building a Decision-Tree model. The problem of overfitting is considered when the algorithm continues to go deeper and deeper to reduce the training-set error but results with an increased test-set error. So, accuracy of prediction for our model goes down. It generally happens when we build many branches due to outliers and irregularities in data.
#
# Two approaches which can be used to avoid overfitting are as follows:-
#
# Pre-Pruning
#
# Post-Pruning

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns 
# %matplotlib inline

# %%
import warnings

warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('/content/car_evaluation (1).csv', header=None)
df.head()
# Out:
#        0      1  2  3      4     5      6
# 0  vhigh  vhigh  2  2  small   low  unacc
# 1  vhigh  vhigh  2  2  small   med  unacc
# 2  vhigh  vhigh  2  2  small  high  unacc
# 3  vhigh  vhigh  2  2    med   low  unacc
# 4  vhigh  vhigh  2  2    med   med  unacc

# %%
df.shape
# Out:
# (1728, 7)

# %%
df.head()
# Out:
#        0      1  2  3      4     5      6
# 0  vhigh  vhigh  2  2  small   low  unacc
# 1  vhigh  vhigh  2  2  small   med  unacc
# 2  vhigh  vhigh  2  2  small  high  unacc
# 3  vhigh  vhigh  2  2    med   low  unacc
# 4  vhigh  vhigh  2  2    med   med  unacc

# %%
for i in df['doors']:
    print(i+'2')
# Out:
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 32
# 32
# 32
# 32
# 32
# 32
# 32
# 32
# 32
# 32
# 32
# 32
# 32
# 32
# 32
# 32
# 32
# 32
# 32
# 32
# 32
# 32
# 32
# 32
# 32
# 32
# 32
# 42
# 42
# 42
# 42
# 42
# 42
# 42
# 42
# 42
# 42
# 42
# 42
# 42
# 42
# 42
# 42
# 42
# 42
# 42
# 42
# 42
# 42
# 42
# 42
# 42
# 42
# 42
# 5more2
# 5more2
# 5more2
# 5more2
# 5more2
# 5more2
# 5more2
# 5more2
# 5more2
# 5more2
# 5more2
# 5more2
# 5more2
# 5more2
# 5more2
# 5more2
# 5more2
# 5more2
# 5more2
# 5more2
# 5more2
# 5more2
# 5more2
# 5more2
# 5more2
# 5more2
# 5more2
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 22
# 32
# 32
# 32
# 32
# 32
# 32
# 32
# 32
# 32
# 32
# 32
# 32
# 32
# 32
# 32
# 32
# 32
# 32
# 32
# 32
# 32
# 32
# 32
# 32
# 32
# 32
# 32
# 42
# 42
# 42
# 42
# 42
# 42
# 42
# 42
# 42
# 42
# 42
# 42
# 42
# 42
# 42
# 42
# ...

# %%
col_names = ['buying', 'maint', 'doors', 'persons', 'lug_boot', 'safety', 'class']


df.columns = col_names

col_names
# Out:
# ['buying', 'maint', 'doors', 'persons', 'lug_boot', 'safety', 'class']

# %%
df.head()
# Out:
#   buying  maint doors persons lug_boot safety  class
# 0  vhigh  vhigh     2       2    small    low  unacc
# 1  vhigh  vhigh     2       2    small    med  unacc
# 2  vhigh  vhigh     2       2    small   high  unacc
# 3  vhigh  vhigh     2       2      med    low  unacc
# 4  vhigh  vhigh     2       2      med    med  unacc

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1728 entries, 0 to 1727
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   buying    1728 non-null   object
#  1   maint     1728 non-null   object
#  2   doors     1728 non-null   object
#  3   persons   1728 non-null   object
#  4   lug_boot  1728 non-null   object
#  5   safety    1728 non-null   object
#  6   class     1728 non-null   object
# dtypes: object(7)
# memory usage: 94.6+ KB

# %%
df['buying'].value_counts()
# Out:
# vhigh    432
# high     432
# med      432
# low      432
# Name: buying, dtype: int64

# %%
df['buying']
# Out:
# 0       vhigh
# 1       vhigh
# 2       vhigh
# 3       vhigh
# 4       vhigh
#         ...
# 1723      low
# 1724      low
# 1725      low
# 1726      low
# 1727      low
# Name: buying, Length: 1728, dtype: object

# %%
df['buying'].apply(lambda x: x+'1')
# Out:
# 0       vhigh1
# 1       vhigh1
# 2       vhigh1
# 3       vhigh1
# 4       vhigh1
#          ...
# 1723      low1
# 1724      low1
# 1725      low1
# 1726      low1
# 1727      low1
# Name: buying, Length: 1728, dtype: object

# %%
# Jupyter, Spyder, VSCODE, Pycharm, Jupyter LAB, Google COlab

# %%
for mehrab in col_names:
    print(mehrab+'1')
# Out:
# buying1
# maint1
# doors1
# persons1
# lug_boot1
# safety1
# class1

# %%
df['doors'].value_counts()
# Out:
# 2        432
# 3        432
# 4        432
# 5more    432
# Name: doors, dtype: int64

# %%
col_names = ['buying', 'maint', 'doors', 'persons', 'lug_boot', 'safety', 'class']
for col in col_names:
    print(df[col].value_counts())
# Out:
# vhigh    432
# high     432
# med      432
# low      432
# Name: buying, dtype: int64
# vhigh    432
# high     432
# med      432
# low      432
# Name: maint, dtype: int64
# 2        432
# 3        432
# 4        432
# 5more    432
# Name: doors, dtype: int64
# 2       576
# 4       576
# more    576
# Name: persons, dtype: int64
# small    576
# med      576
# big      576
# Name: lug_boot, dtype: int64
# low     576
# med     576
# high    576
# Name: safety, dtype: int64
# unacc    1210
# acc       384
# good       69
# vgood      65
# Name: class, dtype: int64

# %%
df['class'].value_counts()# Target(Dependent)
# Out:
# unacc    1210
# acc       384
# good       69
# vgood      65
# Name: class, dtype: int64

# %%
df.isnull().sum()
# Out:
# buying      0
# maint       0
# doors       0
# persons     0
# lug_boot    0
# safety      0
# class       0
# dtype: int64

# %%
X = df.drop(['class'], axis=1)

y = df['class']

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state = 42)

# %%
X_train.shape, X_test.shape
# Out:
# ((1296, 6), (432, 6))

# %%
X_train.dtypes
# Out:
# buying      object
# maint       object
# doors       object
# persons     object
# lug_boot    object
# safety      object
# dtype: object

# %%
X_train.head()
# Out:
#      buying  maint doors persons lug_boot safety
# 1036    med   high     4       4    small    med
# 757    high    low     2       2    small    med
# 589    high   high     3    more      med    med
# 907     med  vhigh     3       4      big    med
# 1159    med    med     4    more      big    med

# %%
import category_encoders as ce# alias

# %%
#encode variables with ordinal(Order) encoding

encoder = ce.OrdinalEncoder(cols=['buying', 'maint', 'doors', 'persons', 'lug_boot', 'safety'])
X_train = encoder.fit_transform(X_train)

X_test = encoder.transform(X_test)

# %%
X_train.head()
# Out:
#       buying  maint  doors  persons  lug_boot  safety
# 1036       1      1      1        1         1       1
# 757        2      2      2        2         1       1
# 589        2      1      3        3         2       1
# 907        1      3      3        1         3       1
# 1159       1      4      1        3         3       1

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
clf_gini = DecisionTreeClassifier(criterion='gini', random_state=0)


# fit the model
clf_gini.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(random_state=0)

# %%
X_test.head()
# Out:
#       buying  maint  doors  persons  lug_boot  safety
# 599        2      1      1        2         2       2
# 1201       1      2      2        1         2       1
# 628        2      1      4        2         3       1
# 1498       3      1      4        1         2       1
# 1263       1      2      1        3         2       3

# %%
clf_gini.predict([[2, 3,4,5]])

# %%
y_pred_gini = clf_gini.predict(X_test)

# %%
from sklearn.metrics import accuracy_score

print(accuracy_score(y_test, y_pred_gini))
# Out:
# 0.8958333333333334

# %%
y_pred_train_gini = clf_gini.predict(X_train)

y_pred_train_gini
# Out:
# array(['unacc', 'unacc', 'acc', ..., 'acc', 'unacc', 'acc'], dtype=object)

# %%
print('Training-set accuracy score',accuracy_score(y_train, y_pred_train_gini))
# Out:
# Training-set accuracy score 1.0

# %% [markdown]
# # Check for overfitting and underfitting

# %%
print('Training set score: {:.4f}'.format(clf_gini.score(X_train, y_train)))

print('Test set score: {:.4f}'.format(clf_gini.score(X_test, y_test)))
# Out:
# Training set score: 1.0000
# Test set score: 0.8958

# %% [markdown]
# the training-set accuracy score is 0.7865 while the test-set accuracy to be 0.8021. These two values are quite comparable. So, there is no sign of overfitting.

# %%
plt.figure(figsize=(12,8))

from sklearn import tree

tree.plot_tree(clf_gini.fit(X_train, y_train))
# Out:
# [Text(356.3237575301205, 420.384, 'X[5] <= 2.5\ngini = 0.45\nsamples = 1296\nvalue = [281, 54, 916, 45]'),
#  Text(352.29002259036145, 391.392, 'X[3] <= 1.5\ngini = 0.576\nsamples = 856\nvalue = [281, 54, 476, 45]'),
#  Text(228.59932228915662, 362.4, 'X[0] <= 3.5\ngini = 0.634\nsamples = 294\nvalue = [145, 29, 96, 24]'),
#  Text(166.76972891566263, 333.408, 'X[5] <= 1.5\ngini = 0.636\nsamples = 220\nvalue = [117, 29, 50, 24]'),
#  Text(111.17981927710842, 304.416, 'X[4] <= 2.5\ngini = 0.6\nsamples = 111\nvalue = [55, 15, 41, 0]'),
#  Text(73.11144578313252, 275.424, 'X[0] <= 2.5\ngini = 0.555\nsamples = 73\nvalue = [30, 5, 38, 0]'),
#  Text(49.41325301204819, 246.432, 'X[0] <= 1.5\ngini = 0.462\nsamples = 50\nvalue = [16, 1, 33, 0]'),
#  Text(30.25301204819277, 217.44, 'X[1] <= 3.5\ngini = 0.533\nsamples = 22\nvalue = [12, 1, 9, 0]'),
#  Text(26.219277108433733, 188.44799999999998, 'X[2] <= 3.5\ngini = 0.524\nsamples = 15\nvalue = [5, 1, 9, 0]'),
# ...

# %%
clf_en = DecisionTreeClassifier(criterion='entropy', max_depth=7, random_state=0)


# fit the model
clf_en.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=7, random_state=0)

# %%
y_pred_en = clf_en.predict(X_test)

# %%
from sklearn.metrics import accuracy_score

print('Model accuracy score with criterion entropy: {0:0.4f}'. format(accuracy_score(y_test, y_pred_en)))
# Out:
# Model accuracy score with criterion entropy: 0.8519

# %%
y_pred_train_en = clf_en.predict(X_train)

y_pred_train_en
# Out:
# array(['acc', 'unacc', 'acc', ..., 'acc', 'unacc', 'unacc'], dtype=object)

# %%
print('Training-set accuracy score: {0:0.4f}'. format(accuracy_score(y_train, y_pred_train_en)))
# Out:
# Training-set accuracy score: 0.8789

# %%
print('Training set score: {:.4f}'.format(clf_en.score(X_train, y_train)))

print('Test set score: {:.4f}'.format(clf_en.score(X_test, y_test)))
# Out:
# Training set score: 0.8789
# Test set score: 0.8519

# %% [markdown]
# the training-set score and test-set score is same as above. The training-set accuracy score is 0.7865 while the test-set accuracy to be 0.8021. These two values are quite comparable. So, there is no sign of overfitting.

# %%
plt.figure(figsize=(12,8))

from sklearn import tree

tree.plot_tree(clf_en.fit(X_train, y_train))
# Out:
# [Text(421.115625, 407.7, 'X[5] <= 2.5\nentropy = 1.191\nsamples = 1296\nvalue = [281, 54, 916, 45]'),
#  Text(410.653125, 353.34000000000003, 'X[3] <= 1.5\nentropy = 1.473\nsamples = 856\nvalue = [281, 54, 476, 45]'),
#  Text(272.02500000000003, 298.98, 'X[0] <= 3.5\nentropy = 1.655\nsamples = 294\nvalue = [145, 29, 96, 24]'),
#  Text(167.4, 244.62, 'X[5] <= 1.5\nentropy = 1.704\nsamples = 220\nvalue = [117, 29, 50, 24]'),
#  Text(83.7, 190.26, 'X[4] <= 2.5\nentropy = 1.423\nsamples = 111\nvalue = [55, 15, 41, 0]'),
#  Text(41.85, 135.89999999999998, 'X[0] <= 2.5\nentropy = 1.282\nsamples = 73\nvalue = [30, 5, 38, 0]'),
#  Text(20.925, 81.54000000000002, 'X[0] <= 1.5\nentropy = 1.035\nsamples = 50\nvalue = [16, 1, 33, 0]'),
#  Text(10.4625, 27.180000000000007, 'entropy = 1.207\nsamples = 22\nvalue = [12, 1, 9, 0]'),
#  Text(31.387500000000003, 27.180000000000007, 'entropy = 0.592\nsamples = 28\nvalue = [4, 0, 24, 0]'),
# ...

# %%
from sklearn.metrics import confusion_matrix # Evaluation of the model
cm = confusion_matrix(y_test, y_pred_en)

print('Confusion matrix\n\n', cm)
# Out:
# Confusion matrix
#
#  [[ 78   3  12  10]
#  [ 10   3   1   1]
#  [ 18   0 276   0]
#  [  8   1   0  11]]

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test, y_pred_en))
# Out:
#               precision    recall  f1-score   support
#
#          acc       0.56      0.57      0.56       129
#         good       0.00      0.00      0.00        20
#        unacc       0.87      0.97      0.92       397
#        vgood       0.00      0.00      0.00        25
#
#     accuracy                           0.80       571
#    macro avg       0.36      0.38      0.37       571
# weighted avg       0.73      0.80      0.77       571

# %% [markdown]
# https://www.youtube.com/watch?v=1IQOtJ4NI_0

# %% [markdown]
# https://www.youtube.com/watch?v=FuTRucXB9rA

# %% [markdown]
# `Whichever has Higher Decision Tree Information Gain that kind of structure decision tree will be taken.`
# ![DecisionTree_information_gain.PNG](attachment:DecisionTree_information_gain.PNG)

# %%
# Gini Impurity will take shorter time to execute a problem

# %% [markdown]
# https://www.youtube.com/watch?v=5aIFgrrTqOw

# %% [markdown]
# https://www.youtube.com/watch?v=SLOyyFHbiqo

# %% [markdown]
# https://github.com/krishnaik06/Post_P...

# %% [markdown]
# Decision Tree Split For Numerical Feature
# https://www.youtube.com/watch?v=5O8HvA9pMew&list=PLZoTAELRMXVPBTrWtJkn3wWQxZkmTXGwe&index=53
