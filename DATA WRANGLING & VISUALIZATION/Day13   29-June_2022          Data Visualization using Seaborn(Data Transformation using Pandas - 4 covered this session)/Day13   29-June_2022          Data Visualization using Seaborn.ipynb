# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from PIL import Image as im
import numpy as np

# %%
df=pd.read_csv(r"D:\Data Science\DATA WRANGLING & VISUALIZATION\creditcard.csv")
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
# 'bar_label' function is basically for put the number over the bars

# %% [markdown]
# ### Today's class is about to create pivot table in python

# %%
df1=pd.DataFrame({'A':['One','Two','Three','Four','Five'],
                 'B':['Uttam','Ajay','Pooja','Vaibhav','Usha'],
                 'C':[1,2,3,4,5],
                 'D':[10,20,30,40,50]})

# %%
df1
# Out:
#        A        B  C   D
# 0    One    Uttam  1  10
# 1    Two     Ajay  2  20
# 2  Three    Pooja  3  30
# 3   Four  Vaibhav  4  40
# 4   Five     Usha  5  50

# %%
pd.pivot_table(df1, index=['A'], columns=['B'], aggfunc=np.sum, values=["D"])
# Out:
#           D
# B      Ajay Pooja  Usha Uttam Vaibhav
# A
# Five    NaN   NaN  50.0   NaN     NaN
# Four    NaN   NaN   NaN   NaN    40.0
# One     NaN   NaN   NaN  10.0     NaN
# Three   NaN  30.0   NaN   NaN     NaN
# Two    20.0   NaN   NaN   NaN     NaN

# %%
pd.pivot_table(df1, index=['A','D'], columns=['B'], aggfunc=np.sum)
# Out:
#             C
# B        Ajay Pooja Usha Uttam Vaibhav
# A     D
# Five  50  NaN   NaN  5.0   NaN     NaN
# Four  40  NaN   NaN  NaN   NaN     4.0
# One   10  NaN   NaN  NaN   1.0     NaN
# Three 30  NaN   3.0  NaN   NaN     NaN
# Two   20  2.0   NaN  NaN   NaN     NaN

# %%
df2=pd.read_csv(r"D:\Data Science\DATA WRANGLING & VISUALIZATION\netflix_titles.csv")
df2.head(2)
# Out:
#   show_id     type title           director  \
# 0      s1  TV Show    3%                NaN
# 1      s2    Movie  7:19  Jorge Michel Grau
#
#                                                 cast country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico
#
#           date_added  release_year rating   duration  \
# 0    August 14, 2020          2020  TV-MA  4 Seasons
# 1  December 23, 2016          2016  TV-MA     93 min
#
#                                            listed_in  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
#
#                                          description
# 0  In a future where the elite inhabit an island ...
# 1  After a devastating earthquake hits Mexico Cit...

# %%
a=pd.pivot_table(df2, index=['type','date_added','listed_in'], columns=['country'], aggfunc=np.sum, values=['title'],fill_value='-')
# here 'index' will work as a 'row' function in pivot table , 'columns' will work as a 'column'
# 'aggfunc' will work as a 'values' and 'fill_value' will change the null value into whichever value is given 
# into this function

# %%
a
# Out:
#                                                                                   title  \
# country                                                                       Argentina
# type    date_added         listed_in
# Movie   April 1, 2016      Documentaries                                              -
#                            Documentaries, Music & Musicals                            -
#                            Documentaries, Sports Movies                               -
#         April 1, 2017      Documentaries                                              -
#                            Action & Adventure, Cult Movies, International ...         -
# ...                                                                                 ...
# TV Show September 25, 2020 British TV Shows, Reality TV                               -
#         September 27, 2020 International TV Shows, TV Action & Adventure, ...         -
# ...

# %%
df3=pd.DataFrame({'A':['One','Two','Three','Four','Five','Six','Seven','Eight'],
                 'B':['Uttam','Ajay','Pooja','Vaibhav','Usha','Sujan','Bushan','Kiran'],
                 'C':['Large','Small','Medium','Big','Little','New','Old','Young'],
                 'D':[99,98,30,40,50,80,70,11],
                 'E':[11,37,33,21,15,99,26,45]    })
df3.head()
# Out:
#        A        B       C   D   E
# 0    One    Uttam   Large  99  11
# 1    Two     Ajay   Small  98  37
# 2  Three    Pooja  Medium  30  33
# 3   Four  Vaibhav     Big  40  21
# 4   Five     Usha  Little  50  15

# %%
pd.pivot_table(df3, index=['A','C'], aggfunc={'D':np.mean,'E':np.sum}, values=['D','E'])
# here we mentioned 'aggfunc={'D':np.mean,'E':np.sum}' to mention different values like sum, mean, etc.
# Out:
#                D   E
# A     C
# Eight Young   11  45
# Five  Little  50  15
# Four  Big     40  21
# One   Large   99  11
# Seven Old     70  26
# Six   New     80  99
# Three Medium  30  33
# Two   Small   98  37

# %%
pd.pivot_table(df3, index=['A','C'], aggfunc={'D':np.mean,'E':[np.sum,max,min]}, values=['D','E'])
# Out:
#                  D   E
#               mean max min sum
# A     C
# Eight Young   11.0  45  45  45
# Five  Little  50.0  15  15  15
# Four  Big     40.0  21  21  21
# One   Large   99.0  11  11  11
# Seven Old     70.0  26  26  26
# Six   New     80.0  99  99  99
# Three Medium  30.0  33  33  33
# Two   Small   98.0  37  37  37

# %%
df5=pd.read_csv(r"D:\Data Science\DATA WRANGLING & VISUALIZATION\train (8).csv")
df5.head(3)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S

# %%
pd.pivot_table(df5,index=['Sex'])
# Out:
#               Age       Fare     Parch  PassengerId    Pclass     SibSp  \
# Sex
# female  27.915709  44.479818  0.649682   431.028662  2.159236  0.694268
# male    30.726645  25.523893  0.235702   454.147314  2.389948  0.429809
#
#         Survived
# Sex
# female  0.742038
# male    0.188908

# %%
b=pd.pivot_table(df5,index=['Sex'])
b.plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Sex'>

# %%
pd.pivot_table(df5,index=['Sex','Pclass'])
# Out:
#                      Age        Fare     Parch  PassengerId     SibSp  \
# Sex    Pclass
# female 1       34.611765  106.125798  0.457447   469.212766  0.553191
#        2       28.722973   21.970121  0.605263   443.105263  0.486842
#        3       21.750000   16.118810  0.798611   399.729167  0.895833
# male   1       41.281386   67.226127  0.278689   455.729508  0.311475
#        2       30.740707   19.741782  0.222222   447.962963  0.342593
#        3       26.507589   12.661633  0.224784   455.515850  0.498559
#
#                Survived
# Sex    Pclass
# female 1       0.968085
#        2       0.921053
#        3       0.500000
# male   1       0.368852
#        2       0.157407
#        3       0.135447

# %%
pd.pivot_table(df5,index=['Sex','Pclass'],aggfunc={'Age':np.mean,'Survived':np.sum})
# Out:
#                      Age  Survived
# Sex    Pclass
# female 1       34.611765        91
#        2       28.722973        70
#        3       21.750000        72
# male   1       41.281386        45
#        2       30.740707        17
#        3       26.507589        47

# %%
pd.pivot_table(df5,index=['Sex','Pclass','Survived'],aggfunc={'Age':np.mean,'Survived':np.sum}) 
# we can't directly use 'count' function here, because numpy won't support here so that we followed another method
# Out:
#                               Age  Survived
# Sex    Pclass Survived
# female 1      0         25.666667         0
#               1         34.939024        91
#        2      0         36.000000         0
#               1         28.080882        70
#        3      0         23.818182         0
#               1         19.329787        72
# male   1      0         44.581967         0
#               1         36.248000        45
#        2      0         33.369048         0
#               1         16.022000        17
#        3      0         27.255814         0
#               1         22.274211        47

# %%
df6=pd.read_csv(r"D:\Data Science\DATA WRANGLING & VISUALIZATION\catalog.csv")
df6.head(3)
# Out:
#    id     date   time continent_code   country_name country_code  \
# 0  34   3/2/07  Night            NaN  United States           US
# 1  42  3/22/07    NaN            NaN  United States           US
# 2  56   4/6/07    NaN            NaN  United States           US
#
#   state/province  population         city/town  distance  ...  \
# 0       Virginia       16000       Cherry Hill   3.40765  ...
# 1           Ohio       17288  New Philadelphia   3.33522  ...
# 2   Pennsylvania       15930       Wilkinsburg   2.91977  ...
#
#                                  geolocation  hazard_type  landslide_type  \
# 0  (38.600900000000003, -77.268199999999993)    Landslide       Landslide
# 1  (40.517499999999998, -81.430499999999995)    Landslide       Landslide
# 2             (40.4377, -79.915999999999997)    Landslide       Landslide
#
#   landslide_size trigger storm_name injuries fatalities  \
# 0          Small    Rain        NaN      NaN        NaN
# ...

# %%
df6['date'] # it should be in 'Datetime' formate
# Out:
# 0         3/2/07
# 1        3/22/07
# 2         4/6/07
# 3        4/14/07
# 4        4/15/07
# 5        4/20/07
# 6        4/24/07
# 7        5/21/07
# 8        6/27/07
# 9        6/27/07
# 10       6/27/07
# 11        7/1/07
# 12        7/4/07
# 13        7/8/07
# 14       7/13/07
# 15       7/24/07
# 16        8/9/07
# 17       8/11/07
# 18       8/14/07
# 19       8/17/07
# 20       8/18/07
# 21       8/18/07
# 22       8/18/07
# 23       8/19/07
# 24       8/19/07
# 25       8/20/07
# 26       8/21/07
# 27       8/21/07
# 28       8/23/07
# 29        9/1/07
# 30        9/2/07
# 31        9/3/07
# 32        9/4/07
# 33        9/5/07
# 34        9/5/07
# 35        9/5/07
# 36        9/6/07
# 37        9/9/07
# 38        9/9/07
# 39       9/17/07
# 40       9/22/07
# 41       9/28/07
# 42       10/8/07
# 43       10/9/07
# 44      10/11/07
# 45      10/11/07
# 46      10/12/07
# 47      10/12/07
# 48      10/13/07
# 49      10/17/07
# 50      10/24/07
# 51      10/29/07
# ...

# %%
df6['date'].dtype # checking date type
# Out:
# dtype('O')

# %%
a=pd.to_datetime(df6['date']) # here date is not in format  of month/date/year
a
# Out:
# 0      2007-03-02
# 1      2007-03-22
# 2      2007-04-06
# 3      2007-04-14
# 4      2007-04-15
# 5      2007-04-20
# 6      2007-04-24
# 7      2007-05-21
# 8      2007-06-27
# 9      2007-06-27
# 10     2007-06-27
# 11     2007-07-01
# 12     2007-07-04
# 13     2007-07-08
# 14     2007-07-13
# 15     2007-07-24
# 16     2007-08-09
# 17     2007-08-11
# 18     2007-08-14
# 19     2007-08-17
# 20     2007-08-18
# 21     2007-08-18
# 22     2007-08-18
# 23     2007-08-19
# 24     2007-08-19
# 25     2007-08-20
# 26     2007-08-21
# 27     2007-08-21
# 28     2007-08-23
# 29     2007-09-01
# 30     2007-09-02
# 31     2007-09-03
# 32     2007-09-04
# 33     2007-09-05
# 34     2007-09-05
# 35     2007-09-05
# 36     2007-09-06
# 37     2007-09-09
# 38     2007-09-09
# 39     2007-09-17
# 40     2007-09-22
# 41     2007-09-28
# 42     2007-10-08
# 43     2007-10-09
# 44     2007-10-11
# 45     2007-10-11
# 46     2007-10-12
# 47     2007-10-12
# 48     2007-10-13
# 49     2007-10-17
# ...

# %%
a.dtype
# Out:
# dtype('<M8[ns]')

# %%
df6['new_date']=pd.to_datetime(df6['date']).dt.strftime('%m/%d/%Y') # here we changed date format to month/date/year
df6.head(3)
# Out:
#    id     date   time continent_code   country_name country_code  \
# 0  34   3/2/07  Night            NaN  United States           US
# 1  42  3/22/07    NaN            NaN  United States           US
# 2  56   4/6/07    NaN            NaN  United States           US
#
#   state/province  population         city/town  distance  ... hazard_type  \
# 0       Virginia       16000       Cherry Hill   3.40765  ...   Landslide
# 1           Ohio       17288  New Philadelphia   3.33522  ...   Landslide
# 2   Pennsylvania       15930       Wilkinsburg   2.91977  ...   Landslide
#
#    landslide_type  landslide_size trigger storm_name injuries fatalities  \
# 0       Landslide           Small    Rain        NaN      NaN        NaN
# 1       Landslide           Small    Rain        NaN      NaN        NaN
# 2       Landslide           Small    Rain        NaN      NaN        NaN
#
#                   source_name  \
# 0                  NBC 4 news
# 1              Canton Rep.com
# ...

# %%
pd.set_option('display.max_rows', None)  # to see full dataframe

# %%
df6['new_date'].dt.day
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [114], in <cell line: 1>()
# ----> 1 df6['new_date'].dt.day
#
# File D:\Data Science\edyodha packages\lib\site-packages\pandas\core\generic.py:5575, in NDFrame.__getattr__(self, name)
#    5568 if (
#    5569     name not in self._internal_names_set
#    5570     and name not in self._metadata
#    5571     and name not in self._accessors
#    5572     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5573 ):
#    5574     return self[name]
# -> 5575 return object.__getattribute__(self, name)
#
# File D:\Data Science\edyodha packages\lib\site-packages\pandas\core\accessor.py:182, in CachedAccessor.__get__(self, obj, cls)
#     179 if obj is None:
#     180     # we're accessing the attribute of the class, i.e., Dataset.geo
#     181     return self._accessor
# --> 182 accessor_obj = self._accessor(obj)
# ...
