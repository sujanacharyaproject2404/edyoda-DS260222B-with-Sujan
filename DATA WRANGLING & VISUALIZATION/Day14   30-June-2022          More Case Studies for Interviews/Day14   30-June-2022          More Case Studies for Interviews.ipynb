# %% [markdown]
# # Data Visualization using Seaborn topics covered this session

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# 1. Data Collection
# 2. Data Cleaning, Wrangling/Visualization
# 3. Data Engineering
# 4. Machine Learning Model
# 5. Decision Making

# %%
# Dash Board:
           # It contains a data Data Set (Whole summary of data)

# %%
# Visualization:
            # It's a small chunk of finding sata.

# %%
df=pd.read_csv(r"D:\Data Science\DATA WRANGLING & VISUALIZATION\train (8).csv")
df.head(3)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S

# %%
sns.catplot(x='Sex', y='Survived',data=df)

# %%
sns.catplot(x='Sex', y='Survived',data=df, kind='bar') # here we have mentioned 'kind = bar' function to get 'bar chart'

# %%
sns.catplot(y='Sex', x='Survived',data=df, kind='bar')

# %%
# black vertex line is coming under catplot only.

# %%
sns.catplot(x='SibSp', y='Survived',data=df, kind='bar')

# %%
df['Sex'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
sns.catplot(x='SibSp', y='Survived',data=df, kind='strip') # 'strip chart' is not available in 'bar chart'

# %%
df.head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked
# 0      0  A/5 21171   7.2500   NaN        S
# 1      0   PC 17599  71.2833   C85        C

# %%
sns.catplot(x='SibSp', y='Survived',data=df, hue='Embarked')

# %%
sns.catplot(x='SibSp', y='Survived',data=df, hue='Embarked', kind='bar')

# %%
sns.catplot(x='SibSp', y='Survived',data=df, hue='Embarked', kind='bar',palette='Set2') # changing color with the help of
                                                                                        # 'palette'

# %%
sns.barplot(x='Sex',y='Survived', data=df)
# Out:
# <AxesSubplot:xlabel='Sex', ylabel='Survived'>

# %%
# need to know about 'jitter' function

# %%
sns.distplot(df['Parch'])
# Out:
# D:\Data Science\edyodha packages\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Parch', ylabel='Density'>

# %%
sns.distplot(df['Parch'], kde=False)
# Out:
# D:\Data Science\edyodha packages\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Parch'>

# %%
sns.distplot(df['Parch'], hist=False)
# Out:
# D:\Data Science\edyodha packages\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Parch', ylabel='Density'>

# %%
# in array we don't require to pass index

# %% [markdown]
# #### Why array is faster than series

# %%
# Ans: series has two locations one is index and another one is value, but array can store the value where the index is, 
#(backside of the python) so array is faster than series.

# %%
# Pair Plot
sns.pairplot(df) # it will show a pair for each and every column.

# %%
sns.pairplot(df, diag_kind='kde') # diag_kind='kde' fro changing chart in hist and kde
# there is a 'marker' function in 'pairplot' which can chane color and shape

# %%
# Joint Plot


sns.jointplot(x='Fare', y='Age', data=df)  # it will joint plot together

# %%
df.head(3)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S

# %%
# Box plot

# it is basically used for out layers
sns.barplot(x='Pclass', y='Age', data=df)
# Out:
# <AxesSubplot:xlabel='Pclass', ylabel='Age'>

# %%
sns.swarmplot(x='Pclass', y='Age', data=df)
# Out:
# D:\Data Science\edyodha packages\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 11.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <AxesSubplot:xlabel='Pclass', ylabel='Age'>

# %%
# heatmap

# it is used to see a co-relation.

corr = df.corr()
sns.heatmap(corr)
# Out:
# <AxesSubplot:>

# %%
corr = df.corr()
corr
# Out:
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.005007 -0.035144  0.036847 -0.057527 -0.001652
# Survived       -0.005007  1.000000 -0.338481 -0.077221 -0.035322  0.081629
# Pclass         -0.035144 -0.338481  1.000000 -0.369226  0.083081  0.018443
# Age             0.036847 -0.077221 -0.369226  1.000000 -0.308247 -0.189119
# SibSp          -0.057527 -0.035322  0.083081 -0.308247  1.000000  0.414838
# Parch          -0.001652  0.081629  0.018443 -0.189119  0.414838  1.000000
# Fare            0.012658  0.257307 -0.549500  0.096067  0.159651  0.216225
#
#                  Fare
# PassengerId  0.012658
# Survived     0.257307
# Pclass      -0.549500
# Age          0.096067
# SibSp        0.159651
# Parch        0.216225
# Fare         1.000000

# %%
corr = df.corr()
sns.heatmap(corr, annot=True) # for annotation
# Out:
# <AxesSubplot:>

# %%
corr = df.corr()
sns.heatmap(corr, annot=True, cmap='cool') # 'cmap' is for to change color
# Out:
# <AxesSubplot:>
