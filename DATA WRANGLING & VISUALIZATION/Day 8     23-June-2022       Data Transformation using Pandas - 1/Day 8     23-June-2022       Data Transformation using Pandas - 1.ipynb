# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
vb = pd.read_csv(r'C:\Users\91897\Desktop\train (8).csv')
vb.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# One column - Univariate
# MOre than one columns - Bivariate

# %%
vb.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %% [markdown]
# ### Data Tranformation(prepare):

# %%
It helps to transfer data from one way to another way.
It transfer data as per the requirement to do machine learning algorithm.

# %%
vb.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
vb.Survived.unique()
# Out:
# array([0, 1], dtype=int64)

# %%
def survive(x):
    a=x
    if a ==1 :
        print("Alive")
    else:
        print("Dead")

# %%
vb['Survived'].apply(lambda x :survive(x))
# Out:
# Dead
# Alive
# Alive
# Alive
# Dead
# Dead
# Dead
# Dead
# Alive
# Alive
# Alive
# Alive
# Dead
# Dead
# Dead
# Alive
# Dead
# Alive
# Dead
# Alive
# Dead
# Alive
# Alive
# Alive
# Dead
# Alive
# Dead
# Dead
# Alive
# Dead
# Dead
# Alive
# Alive
# Dead
# Dead
# Dead
# Alive
# Dead
# Dead
# Alive
# Dead
# Dead
# Dead
# Alive
# Alive
# Dead
# Dead
# Alive
# Dead
# Dead
# Dead
# Dead
# Alive
# Alive
# Dead
# Alive
# Alive
# Dead
# Alive
# Dead
# Dead
# Alive
# Dead
# Dead
# Dead
# Alive
# Alive
# Dead
# Alive
# Dead
# Dead
# Dead
# Dead
# Dead
# Alive
# Dead
# Dead
# Dead
# Alive
# Alive
# Dead
# Alive
# Alive
# Dead
# Alive
# Alive
# Dead
# Dead
# Alive
# Dead
# Dead
# Dead
# Dead
# Dead
# Dead
# Dead
# Dead
# Alive
# Alive
# Dead
# Dead
# Dead
# Dead
# Dead
# Dead
# Dead
# Alive
# Alive
# Dead
# Alive
# Dead
# Dead
# Dead
# Dead
# Dead
# Dead
# Dead
# Dead
# Dead
# Dead
# Dead
# Dead
# Dead
# Alive
# Dead
# Alive
# Dead
# Alive
# Alive
# Dead
# Dead
# Dead
# Dead
# Alive
# Dead
# ...

# %%
vb['Survived'].apply(survive)
# Out:
# Dead
# Alive
# Alive
# Alive
# Dead
# Dead
# Dead
# Dead
# Alive
# Alive
# Alive
# Alive
# Dead
# Dead
# Dead
# Alive
# Dead
# Alive
# Dead
# Alive
# Dead
# Alive
# Alive
# Alive
# Dead
# Alive
# Dead
# Dead
# Alive
# Dead
# Dead
# Alive
# Alive
# Dead
# Dead
# Dead
# Alive
# Dead
# Dead
# Alive
# Dead
# Dead
# Dead
# Alive
# Alive
# Dead
# Dead
# Alive
# Dead
# Dead
# Dead
# Dead
# Alive
# Alive
# Dead
# Alive
# Alive
# Dead
# Alive
# Dead
# Dead
# Alive
# Dead
# Dead
# Dead
# Alive
# Alive
# Dead
# Alive
# Dead
# Dead
# Dead
# Dead
# Dead
# Alive
# Dead
# Dead
# Dead
# Alive
# Alive
# Dead
# Alive
# Alive
# Dead
# Alive
# Alive
# Dead
# Dead
# Alive
# Dead
# Dead
# Dead
# Dead
# Dead
# Dead
# Dead
# Dead
# Alive
# Alive
# Dead
# Dead
# Dead
# Dead
# Dead
# Dead
# Dead
# Alive
# Alive
# Dead
# Alive
# Dead
# Dead
# Dead
# Dead
# Dead
# Dead
# Dead
# Dead
# Dead
# Dead
# Dead
# Dead
# Dead
# Alive
# Dead
# Alive
# Dead
# Alive
# Alive
# Dead
# Dead
# Dead
# Dead
# Alive
# Dead
# ...

# %%
vb.head()
# Out:
#    Survived                                               Name     Sex   Age  \
# 0         0                            Braund, Mr. Owen Harris    male  22.0
# 1         1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2         1                             Heikkinen, Miss. Laina  female  26.0
# 3         1       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4         0                           Allen, Mr. William Henry    male  35.0
#
#    SibSp  Parch            Ticket     Fare Cabin Embarked  class
# 0      1      0         A/5 21171   7.2500   NaN        S  Third
# 1      1      0          PC 17599  71.2833   C85        C  First
# 2      0      0  STON/O2. 3101282   7.9250   NaN        S  Third
# 3      1      0            113803  53.1000  C123        S  First
# 4      0      0            373450   8.0500   NaN        S  Third

# %%
# drop column
vb.drop(['PassengerId'], axis=1) # axis=1 is for column
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
vb.head() # above dropped column is still not droped for that we should save in one variable.
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# drop column
vb=vb.drop(['PassengerId'], axis=1) # axis=1 is for column

# %%
vb.head()  # now column is dropped
# Out:
#    Survived  Pclass                                               Name  \
# 0         0       3                            Braund, Mr. Owen Harris
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2         1       3                             Heikkinen, Miss. Laina
# 3         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4         0       3                           Allen, Mr. William Henry
#
#       Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# 0    male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1  female  38.0      1      0          PC 17599  71.2833   C85        C
# 2  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3  female  35.0      1      0            113803  53.1000  C123        S
# 4    male  35.0      0      0            373450   8.0500   NaN        S

# %%
vb['Pclass']
# Out:
# 0      3
# 1      1
# 2      3
# 3      1
# 4      3
#       ..
# 886    2
# 887    1
# 888    3
# 889    1
# 890    3
# Name: Pclass, Length: 891, dtype: int64

# %%
vb['class'] = vb['Pclass'].map({1:'First', 2:'Second', 3:'Third'})

# %%
vb.head()
# Out:
#    Survived  Pclass                                               Name  \
# 0         0       3                            Braund, Mr. Owen Harris
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2         1       3                             Heikkinen, Miss. Laina
# 3         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4         0       3                           Allen, Mr. William Henry
#
#       Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked  class
# 0    male  22.0      1      0         A/5 21171   7.2500   NaN        S  Third
# 1  female  38.0      1      0          PC 17599  71.2833   C85        C  First
# 2  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S  Third
# 3  female  35.0      1      0            113803  53.1000  C123        S  First
# 4    male  35.0      0      0            373450   8.0500   NaN        S  Third

# %%
vb=vb.drop(['Pclass'],axis=1)

# %%
vb.head()
# Out:
#    Survived                                               Name     Sex   Age  \
# 0         0                            Braund, Mr. Owen Harris    male  22.0
# 1         1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2         1                             Heikkinen, Miss. Laina  female  26.0
# 3         1       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4         0                           Allen, Mr. William Henry    male  35.0
#
#    SibSp  Parch            Ticket     Fare Cabin Embarked  class
# 0      1      0         A/5 21171   7.2500   NaN        S  Third
# 1      1      0          PC 17599  71.2833   C85        C  First
# 2      0      0  STON/O2. 3101282   7.9250   NaN        S  Third
# 3      1      0            113803  53.1000  C123        S  First
# 4      0      0            373450   8.0500   NaN        S  Third

# %%
vb1 = pd.read_csv(r"C:\Users\91897\Desktop\train (7).csv")
vb1
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
vb1['MSSubClass']
# Out:
# 0       60
# 1       20
# 2       60
# 3       70
# 4       60
#         ..
# 1455    60
# 1456    20
# 1457    70
# 1458    20
# 1459    20
# Name: MSSubClass, Length: 1460, dtype: int64

# %%
vb1['MSSubClass'].mean() # it is a statistical function
# Out:
# 56.897260273972606

# %%
vb1['MSSubClass'].median() # it is a statistical function
# Out:
# 50.0

# %%
vb1.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
vb2 = vb.iloc[1:100, 0:4] # first 1:100 is for row and 0:4 is for column

# %%
vb2.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
#
#                                                 Name
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                             Heikkinen, Miss. Laina
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                           Allen, Mr. William Henry
# 5                                   Moran, Mr. James

# %%
vb2 = vb.iloc[:, 0:4]  # first : is for row and 0:4 is for column

# %%
vb2.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name
# 0                            Braund, Mr. Owen Harris
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                             Heikkinen, Miss. Laina
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                           Allen, Mr. William Henry

# %%
frame = [vb,vb2]

# %%
frame
# Out:
# [     PassengerId  Survived  Pclass  \
#  0              1         0       3
#  1              2         1       1
#  2              3         1       3
#  3              4         1       1
#  4              5         0       3
#  ..           ...       ...     ...
#  886          887         0       2
#  887          888         1       1
#  888          889         0       3
#  889          890         1       1
#  890          891         0       3
#
#                                                    Name     Sex   Age  SibSp  \
#  0                              Braund, Mr. Owen Harris    male  22.0      1
#  1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#  2                               Heikkinen, Miss. Laina  female  26.0      0
#  3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
#  4                             Allen, Mr. William Henry    male  35.0      0
# ...

# %%
concatinate = pd.concat(frame)

# %%
concatinate
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0    1.0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0    1.0
# 2                               Heikkinen, Miss. Laina  female  26.0    0.0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0    1.0
# 4                             Allen, Mr. William Henry    male  35.0    0.0
# ..                                                 ...     ...   ...    ...
# ...

# %%
frame1 = [vb,vb2,vb1]

# %%
frame1
# Out:
# [     PassengerId  Survived  Pclass  \
#  0              1         0       3
#  1              2         1       1
#  2              3         1       3
#  3              4         1       1
#  4              5         0       3
#  ..           ...       ...     ...
#  886          887         0       2
#  887          888         1       1
#  888          889         0       3
#  889          890         1       1
#  890          891         0       3
#
#                                                    Name     Sex   Age  SibSp  \
#  0                              Braund, Mr. Owen Harris    male  22.0      1
#  1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#  2                               Heikkinen, Miss. Laina  female  26.0      0
#  3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
#  4                             Allen, Mr. William Henry    male  35.0      0
# ...

# %%
concatinate1 = pd.concat(frame1) # it will add from row wice

# %%
concatinate1
# Out:
#       PassengerId  Survived  Pclass  \
# 0             1.0       0.0     3.0
# 1             2.0       1.0     1.0
# 2             3.0       1.0     3.0
# 3             4.0       1.0     1.0
# 4             5.0       0.0     3.0
# ...           ...       ...     ...
# 1455          NaN       NaN     NaN
# 1456          NaN       NaN     NaN
# 1457          NaN       NaN     NaN
# 1458          NaN       NaN     NaN
# 1459          NaN       NaN     NaN
#
#                                                    Name     Sex   Age  SibSp  \
# 0                               Braund, Mr. Owen Harris    male  22.0    1.0
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0    1.0
# 2                                Heikkinen, Miss. Laina  female  26.0    0.0
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0    1.0
# 4                              Allen, Mr. William Henry    male  35.0    0.0
# ...

# %%
concatinate1 = pd.concat(frame1,axis=1)  # it will add from column wice

# %%
concatinate1
# Out:
#       PassengerId  Survived  Pclass  \
# 0             1.0       0.0     3.0
# 1             2.0       1.0     1.0
# 2             3.0       1.0     3.0
# 3             4.0       1.0     1.0
# 4             5.0       0.0     3.0
# ...           ...       ...     ...
# 1455          NaN       NaN     NaN
# 1456          NaN       NaN     NaN
# 1457          NaN       NaN     NaN
# 1458          NaN       NaN     NaN
# 1459          NaN       NaN     NaN
#
#                                                    Name     Sex   Age  SibSp  \
# 0                               Braund, Mr. Owen Harris    male  22.0    1.0
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0    1.0
# 2                                Heikkinen, Miss. Laina  female  26.0    0.0
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0    1.0
# 4                              Allen, Mr. William Henry    male  35.0    0.0
# ...

# %%
concatinate1 = pd.concat(frame1,axis=1, join='inner') # 'inner join' function will joint entire inside the data

# %%
concatinate1
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
vb.head()
# Out:
#    Survived                                               Name     Sex   Age  \
# 0         0                            Braund, Mr. Owen Harris    male  22.0
# 1         1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2         1                             Heikkinen, Miss. Laina  female  26.0
# 3         1       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4         0                           Allen, Mr. William Henry    male  35.0
#
#    SibSp  Parch            Ticket     Fare Cabin Embarked  class
# 0      1      0         A/5 21171   7.2500   NaN        S  Third
# 1      1      0          PC 17599  71.2833   C85        C  First
# 2      0      0  STON/O2. 3101282   7.9250   NaN        S  Third
# 3      1      0            113803  53.1000  C123        S  First
# 4      0      0            373450   8.0500   NaN        S  Third

# %%
sns.factorplot('class',data=vb, kind='count') # here 'class' means 'class' column
# Out:
# D:\Data Science\edyodha packages\lib\site-packages\seaborn\categorical.py:3717: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# D:\Data Science\edyodha packages\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.factorplot('class',data=vb, kind='count',hue='Survived')
# Out:
# D:\Data Science\edyodha packages\lib\site-packages\seaborn\categorical.py:3717: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# D:\Data Science\edyodha packages\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.factorplot('class',data=vb, kind='count',hue='Sex')
# Out:
# D:\Data Science\edyodha packages\lib\site-packages\seaborn\categorical.py:3717: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# D:\Data Science\edyodha packages\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
vb.head()
# Out:
#    Survived                                               Name     Sex   Age  \
# 0         0                            Braund, Mr. Owen Harris    male  22.0
# 1         1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2         1                             Heikkinen, Miss. Laina  female  26.0
# 3         1       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4         0                           Allen, Mr. William Henry    male  35.0
#
#    SibSp  Parch            Ticket     Fare Cabin Embarked  class
# 0      1      0         A/5 21171   7.2500   NaN        S  Third
# 1      1      0          PC 17599  71.2833   C85        C  First
# 2      0      0  STON/O2. 3101282   7.9250   NaN        S  Third
# 3      1      0            113803  53.1000  C123        S  First
# 4      0      0            373450   8.0500   NaN        S  Third

# %%
vb['Name'].apply(lambda x:x.split(',')) # it will split value into list
# Out:
# 0                             [Braund,  Mr. Owen Harris]
# 1      [Cumings,  Mrs. John Bradley (Florence Briggs ...
# 2                              [Heikkinen,  Miss. Laina]
# 3        [Futrelle,  Mrs. Jacques Heath (Lily May Peel)]
# 4                            [Allen,  Mr. William Henry]
#                              ...
# 886                             [Montvila,  Rev. Juozas]
# 887                      [Graham,  Miss. Margaret Edith]
# 888          [Johnston,  Miss. Catherine Helen "Carrie"]
# 889                             [Behr,  Mr. Karl Howell]
# 890                               [Dooley,  Mr. Patrick]
# Name: Name, Length: 891, dtype: object

# %%
vb['Surname']=vb['Name'].apply(lambda x:x.split(',')[0]) # we have used [0] index here because we want only zero index

# %%
vb['Surname']
# Out:
# 0         Braund
# 1        Cumings
# 2      Heikkinen
# 3       Futrelle
# 4          Allen
#          ...
# 886     Montvila
# 887       Graham
# 888     Johnston
# 889         Behr
# 890       Dooley
# Name: Surname, Length: 891, dtype: object

# %%
vb.head()
# Out:
#    Survived                                               Name     Sex   Age  \
# 0         0                            Braund, Mr. Owen Harris    male  22.0
# 1         1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2         1                             Heikkinen, Miss. Laina  female  26.0
# 3         1       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4         0                           Allen, Mr. William Henry    male  35.0
#
#    SibSp  Parch            Ticket     Fare Cabin Embarked  class    Surname
# 0      1      0         A/5 21171   7.2500   NaN        S  Third     Braund
# 1      1      0          PC 17599  71.2833   C85        C  First    Cumings
# 2      0      0  STON/O2. 3101282   7.9250   NaN        S  Third  Heikkinen
# 3      1      0            113803  53.1000  C123        S  First   Futrelle
# 4      0      0            373450   8.0500   NaN        S  Third      Allen

# %%
vb['Surname'][0]='Uttam'  # converting single value
# Out:
# C:\Windows\Temp\ipykernel_8476\86668806.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vb['Surname'][0]='Uttam'  # converting single value

# %%
vb.head()
# Out:
#    Survived                                               Name     Sex   Age  \
# 0         0                            Braund, Mr. Owen Harris    male  22.0
# 1         1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2         1                             Heikkinen, Miss. Laina  female  26.0
# 3         1       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4         0                           Allen, Mr. William Henry    male  35.0
#
#    SibSp  Parch            Ticket     Fare Cabin Embarked  class    Surname
# 0      1      0         A/5 21171   7.2500   NaN        S  Third      Uttam
# 1      1      0          PC 17599  71.2833   C85        C  First    Cumings
# 2      0      0  STON/O2. 3101282   7.9250   NaN        S  Third  Heikkinen
# 3      1      0            113803  53.1000  C123        S  First   Futrelle
# 4      0      0            373450   8.0500   NaN        S  Third      Allen

# %%
def age_value(x):
    if x<16:
        return 'Child'
    elif x>16 and x<65:
        return 'Adult'
    else:
        return 'Old'

# %%
vb['Age']=vb['Age'].apply(lambda x:age_value(x))  # here assign value to same heading vb['Age']

# %%
vb.head()
# Out:
#    Survived                                               Name     Sex    Age  \
# 0         0                            Braund, Mr. Owen Harris    male  Adult
# 1         1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  Adult
# 2         1                             Heikkinen, Miss. Laina  female  Adult
# 3         1       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  Adult
# 4         0                           Allen, Mr. William Henry    male  Adult
#
#    SibSp  Parch            Ticket     Fare Cabin Embarked  class    Surname
# 0      1      0         A/5 21171   7.2500   NaN        S  Third      Uttam
# 1      1      0          PC 17599  71.2833   C85        C  First    Cumings
# 2      0      0  STON/O2. 3101282   7.9250   NaN        S  Third  Heikkinen
# 3      1      0            113803  53.1000  C123        S  First   Futrelle
# 4      0      0            373450   8.0500   NaN        S  Third      Allen

# %%
sns.factorplot('Age', data=vb, kind='count')
# Out:
# D:\Data Science\edyodha packages\lib\site-packages\seaborn\categorical.py:3717: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# D:\Data Science\edyodha packages\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.factorplot('Age', data=vb, kind='count',hue='Survived')
# Out:
# D:\Data Science\edyodha packages\lib\site-packages\seaborn\categorical.py:3717: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# D:\Data Science\edyodha packages\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.factorplot('Age', data=vb, kind='count',hue='Sex')
# Out:
# D:\Data Science\edyodha packages\lib\site-packages\seaborn\categorical.py:3717: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# D:\Data Science\edyodha packages\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
vb.head()
# Out:
#    Survived                                               Name     Sex    Age  \
# 0         0                            Braund, Mr. Owen Harris    male  Adult
# 1         1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  Adult
# 2         1                             Heikkinen, Miss. Laina  female  Adult
# 3         1       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  Adult
# 4         0                           Allen, Mr. William Henry    male  Adult
#
#    SibSp  Parch            Ticket     Fare Cabin Embarked  class    Surname
# 0      1      0         A/5 21171   7.2500   NaN        S  Third      Uttam
# 1      1      0          PC 17599  71.2833   C85        C  First    Cumings
# 2      0      0  STON/O2. 3101282   7.9250   NaN        S  Third  Heikkinen
# 3      1      0            113803  53.1000  C123        S  First   Futrelle
# 4      0      0            373450   8.0500   NaN        S  Third      Allen

# %%
vb['Fare'].sum()
# Out:
# 28693.9493

# %%
vb.groupby('Sex')['Fare'].sum() # to get sum value by male and female wice
# Out:
# Sex
# female    13966.6628
# male      14727.2865
# Name: Fare, dtype: float64
