# %%
Pandas

# %%
Excellent represent of data
Less coding is required
It can handle large amount of data
It has intensive features(Modules)
Flexile features or it is flexible over the data

# %%
Series and Data Frames

# %%
import pandas as pd
import numpy as np
import seaborn as sns  # it is used for visualization
import matplotlib.pyplot as plt

# %%
# !python -m pip install seaborn

# %%
# !python -m pip install pandas

# %%
pd. show_versions()
# Out:
# INSTALLED VERSIONS
# ------------------
# commit           : 4bfe3d07b4858144c219b9346329027024102ab6
# python           : 3.10.2.final.0
# python-bits      : 64
# OS               : Windows
# OS-release       : 10
# Version          : 10.0.19044
# machine          : AMD64
# processor        : Intel64 Family 6 Model 142 Stepping 9, GenuineIntel
# byteorder        : little
# LC_ALL           : None
# LANG             : None
# LOCALE           : English_India.1252
#
# pandas           : 1.4.2
# numpy            : 1.22.4
# pytz             : 2022.1
# dateutil         : 2.8.2
# pip              : 22.1.2
# setuptools       : 58.1.0
# Cython           : None
# pytest           : 7.1.1
# hypothesis       : None
# sphinx           : None
# blosc            : None
# feather          : None
# xlsxwriter       : None
# lxml.etree       : None
# html5lib         : None
# pymysql          : None
# psycopg2         : None
# jinja2           : 3.0.3
# IPython          : 8.1.1
# ...

# %%
# !pip install pandas

# %% [markdown]
# # Series

# %%
Series data structure represents a column
Each columns will have a data type
Combine multiple columns to create a table(.i.e DataFrame)

# %%
ser1 = pd.Series(data=[1,2,3,4,5], index=list('abcde')) # 'Series' is just like a list
ser1
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# dtype: int64

# %%
pd.Series (data=['Uttam','Pradeep','Charu','Karthik'])
# Out:
# 0      Uttam
# 1    Pradeep
# 2      Charu
# 3    Karthik
# dtype: object

# %%
pd.Series (data=['Uttam','Pradeep','Charu','Karthik'], index = [10,11,12,13])
# Out:
# 10      Uttam
# 11    Pradeep
# 12      Charu
# 13    Karthik
# dtype: object

# %%
ser2=pd.Series (data=['Uttam','Pradeep','Charu','Karthik','Kiran'], index = ['a','b','c','d','e'])
ser2
# Out:
# a      Uttam
# b    Pradeep
# c      Charu
# d    Karthik
# e      Kiran
# dtype: object

# %%
a=['Mentor','Student','Student','Student']

# %%
pd.Series (data=['Uttam','Pradeep','Charu','Karthik'], index = a) # above we have created list to add as a index
# Out:
# Mentor       Uttam
# Student    Pradeep
# Student      Charu
# Student    Karthik
# dtype: object

# %%
import pandas as pd
df = pd.read_csv(r"C:\Users\91897\Desktop\netflix_titles.csv")
df
# Out:
#      show_id     type                                    title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                     7:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7782   s7783    Movie                                     Zozo
# 7783   s7784    Movie                                   Zubaan
# 7784   s7785    Movie                        Zulu Man in Japan
# 7785   s7786  TV Show                    Zumbo's Just Desserts
# 7786   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                director                                               cast  \
# 0                   NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %% [markdown]
# ## Data Frame

# %%
Data Frame is a tabular representation of data
Combine multiple series to create a dataframe
Data corresponding to same index belongs to same row

# %%
df = pd.DataFrame({'A':ser1,'B':ser2})
df
# Out:
#    A        B
# a  1    Uttam
# b  2  Pradeep
# c  3    Charu
# d  4  Karthik
# e  5    Kiran

# %%
df['C']=[10,11,12,13,14]
df
# Out:
#    A        B   C
# a  1    Uttam  10
# b  2  Pradeep  11
# c  3    Charu  12
# d  4  Karthik  13
# e  5    Kiran  14

# %%
df = pd.DataFrame(data = np.random.randint(1,10,size=(10,10)), index=list('ABCDEFGHIJ'), columns=list('abcdefghij'))
df
# Out:
#    a  b  c  d  e  f  g  h  i  j
# A  5  7  2  6  3  9  1  3  8  1
# B  1  5  6  3  4  3  3  1  1  2
# C  9  5  4  2  2  3  6  4  2  8
# D  4  7  3  7  4  7  1  7  7  7
# E  3  4  8  2  2  6  2  6  4  7
# F  4  2  5  5  6  6  2  2  5  2
# G  2  8  7  1  2  2  9  1  6  3
# H  4  5  9  4  8  6  3  4  5  5
# I  3  6  1  3  5  8  1  9  4  6
# J  3  7  7  8  3  7  4  4  1  3

# %%
import pandas as pd
df = pd.read_excel(r"C:\Users\91897\Desktop\pandas.xlsx")
df
# Out:
#     S.No.        Emp_name  Emp_id  Production  Productive Hours  Productivity  \
# 0       1    Vikas Sharma  815864          48              8.00            48
# 1       2          Sachin  815426          58              6.00            77
# 2       3           Rohit  812457          12              4.00            24
# 3       4           Broad  821543          40              7.00            46
# 4       5       Gilchrist  821546          54              8.00            54
# 5       6         Symonds  824513          41              7.00            47
# 6       7         Pollard  875412          42              5.50            61
# 7       8        Mccullum  822135          60              4.00           120
# 8       9     Chris Gayle  821546          46              5.00            74
# 9      10    Morne MorkHD  821354          43              4.67            74
# 10     11    S Shreesanth  811524          51              4.33            94
# ...

# %%
df['name2'][0].replace("_"," ")
# Out:
# 'sujan acharya'

# %%
df['name2'].apply(lambda x: x.replace("_"," ")) # here we used apply function to use lambda method
# Out:
# 0           sujan acharya
# 1           nagendra naik
# 2              shivu naik
# 3            kiran prabhu
# 4        bushhan serughar
# 5           jeevita mesta
# 6            swathi mesta
# 7         pannaga karanth
# 8     subramanya bandekar
# 9          vishu devadiga
# 10           steven souza
# 11            joss butler
# 12            sudeep jain
# 13            tanuja naik
# 14          kavya unknown
# 15              sneha rao
# 16            pooja gowda
# 17             abhi gowda
# Name: name2, dtype: object

# %%
df # here in output _ is not removed for that we should save in one variable or inplace method
# Out:
#     S.No.        Emp_name  Emp_id  Production  Productive Hours  Productivity  \
# 0       1    Vikas Sharma  815864          48              8.00            48
# 1       2          Sachin  815426          58              6.00            77
# 2       3           Rohit  812457          12              4.00            24
# 3       4           Broad  821543          40              7.00            46
# 4       5       Gilchrist  821546          54              8.00            54
# 5       6         Symonds  824513          41              7.00            47
# 6       7         Pollard  875412          42              5.50            61
# 7       8        Mccullum  822135          60              4.00           120
# 8       9     Chris Gayle  821546          46              5.00            74
# 9      10    Morne MorkHD  821354          43              4.67            74
# 10     11    S Shreesanth  811524          51              4.33            94
# ...

# %%
# first method to remove _
df['name2']=df['name2'].apply(lambda x: x.replace("_"," "))
df
# Out:
#     S.No.        Emp_name  Emp_id  Production  Productive Hours  Productivity  \
# 0       1    Vikas Sharma  815864          48              8.00            48
# 1       2          Sachin  815426          58              6.00            77
# 2       3           Rohit  812457          12              4.00            24
# 3       4           Broad  821543          40              7.00            46
# 4       5       Gilchrist  821546          54              8.00            54
# 5       6         Symonds  824513          41              7.00            47
# 6       7         Pollard  875412          42              5.50            61
# 7       8        Mccullum  822135          60              4.00           120
# 8       9     Chris Gayle  821546          46              5.00            74
# 9      10    Morne MorkHD  821354          43              4.67            74
# 10     11    S Shreesanth  811524          51              4.33            94
# ...

# %%
# second method to remove _
df['name2'].apply([lambda x: x.replace("_"," ")],inplace=True) # inplace function we should use after or outside
                                                               # lambda
df
# Out:
#     S.No.        Emp_name  Emp_id  Production  Productive Hours  Productivity  \
# 0       1    Vikas Sharma  815864          48              8.00            48
# 1       2          Sachin  815426          58              6.00            77
# 2       3           Rohit  812457          12              4.00            24
# 3       4           Broad  821543          40              7.00            46
# 4       5       Gilchrist  821546          54              8.00            54
# 5       6         Symonds  824513          41              7.00            47
# 6       7         Pollard  875412          42              5.50            61
# 7       8        Mccullum  822135          60              4.00           120
# 8       9     Chris Gayle  821546          46              5.00            74
# 9      10    Morne MorkHD  821354          43              4.67            74
# 10     11    S Shreesanth  811524          51              4.33            94
# ...

# %%
df['Emp_name'][1]
# Out:
# 'Sachin'

# %%
df['Emp_name'][1].upper() # to make uppercase
# Out:
# 'SACHIN'

# %%
train = pd.read_csv(r"C:\Users\91897\Desktop\train (7).csv")
train
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
train = pd.read_excel(r"C:\Users\91897\Desktop\pandas.xlsx")
train
# Out:
#     Unnamed: 0  S.No.        Emp_name  Emp_id  Production  Productive Hours  \
# 0            1      1    Vikas Sharma  815864          48              8.00
# 1            2      2          Sachin  815426          58              6.00
# 2            3      3           Rohit  812457          12              4.00
# 3            4      4           Broad  821543          40              7.00
# 4            5      5       Gilchrist  821546          54              8.00
# 5            6      6         Symonds  824513          41              7.00
# 6            7      7         Pollard  875412          42              5.50
# 7            8      8        Mccullum  822135          60              4.00
# 8            9      9     Chris Gayle  821546          46              5.00
# 9           10     10    Morne MorkHD  821354          43              4.67
# 10          11     11    S Shreesanth  811524          51              4.33
# ...

# %%
train.head(10)
# Out:
#    Unnamed: 0  S.No.      Emp_name  Emp_id  Production  Productive Hours  \
# 0           1      1  Vikas Sharma  815864          48              8.00
# 1           2      2        Sachin  815426          58              6.00
# 2           3      3         Rohit  812457          12              4.00
# 3           4      4         Broad  821543          40              7.00
# 4           5      5     Gilchrist  821546          54              8.00
# 5           6      6       Symonds  824513          41              7.00
# 6           7      7       Pollard  875412          42              5.50
# 7           8      8      Mccullum  822135          60              4.00
# 8           9      9   Chris Gayle  821546          46              5.00
# 9          10     10  Morne MorkHD  821354          43              4.67
#
#    Productivity                name2
# 0            48        sujan_acharya
# 1            77        nagendra_naik
# 2            24           shivu_naik
# ...

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18 entries, 0 to 17
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        18 non-null     int64
#  1   S.No.             18 non-null     int64
#  2   Emp_name          18 non-null     object
#  3   Emp_id            18 non-null     int64
#  4   Production        18 non-null     int64
#  5   Productive Hours  18 non-null     float64
#  6   Productivity      18 non-null     int64
#  7   name2             18 non-null     object
# dtypes: float64(1), int64(5), object(2)
# memory usage: 1.2+ KB

# %%
train.isnull().sum()
# Out:
# Unnamed: 0          0
# S.No.               0
# Emp_name            0
# Emp_id              0
# Production          0
# Productive Hours    0
# Productivity        0
# name2               0
# dtype: int64

# %%
train.describe()
# Out:
#        Unnamed: 0      S.No.         Emp_id  Production  Productive Hours  \
# count   18.000000  18.000000      18.000000   18.000000         18.000000
# mean     9.500000   9.500000  822008.444444   43.722222          4.880000
# std      5.338539   5.338539   15895.419360   11.431667          1.668113
# min      1.000000   1.000000  811524.000000   12.000000          2.670000
# 25%      5.250000   5.250000  812542.250000   38.250000          3.752500
# 50%      9.500000   9.500000  818609.000000   42.500000          4.165000
# 75%     13.750000  13.750000  821546.000000   53.250000          5.875000
# max     18.000000  18.000000  875412.000000   60.000000          8.000000
#
#        Productivity
# count     18.000000
# mean      78.777778
# std       34.396572
# min       24.000000
# 25%       55.750000
# 50%       75.000000
# 75%       90.000000
# max      168.000000

# %%
train.columns # it will show whole column in one row
# Out:
# Index(['Unnamed: 0', 'S.No.', 'Emp_name', 'Emp_id', 'Production',
#        'Productive Hours', 'Productivity', 'name2'],
#       dtype='object')

# %%
train.rename(columns={train.columns[0]: 'Customer Id'},inplace=True) # 'inplace' will save data automatically
                                                                     # no need to create a varibale to save data

# %%
train.head()
# Out:
#    Customer Id  S.No.      Emp_name  Emp_id  Production  Productive Hours  \
# 0            1      1  Vikas Sharma  815864          48               8.0
# 1            2      2        Sachin  815426          58               6.0
# 2            3      3         Rohit  812457          12               4.0
# 3            4      4         Broad  821543          40               7.0
# 4            5      5     Gilchrist  821546          54               8.0
#
#    Productivity             name2
# 0            48     sujan_acharya
# 1            77     nagendra_naik
# 2            24        shivu_naik
# 3            46      kiran_prabhu
# 4            54  bushhan_serughar

# %%
# remove 
train.drop('S.No.',axis=1) # axis=1 for column and axis=0 for row
# Out:
#     Customer Id        Emp_name  Emp_id  Production  Productive Hours  \
# 0             1    Vikas Sharma  815864          48              8.00
# 1             2          Sachin  815426          58              6.00
# 2             3           Rohit  812457          12              4.00
# 3             4           Broad  821543          40              7.00
# 4             5       Gilchrist  821546          54              8.00
# 5             6         Symonds  824513          41              7.00
# 6             7         Pollard  875412          42              5.50
# 7             8        Mccullum  822135          60              4.00
# 8             9     Chris Gayle  821546          46              5.00
# 9            10    Morne MorkHD  821354          43              4.67
# 10           11    S Shreesanth  811524          51              4.33
# 11           12       Harbhajan  821546          39              4.00
# ...

# %%
train.shape
# Out:
# (18, 8)

# %%
train.groupby('Productivity')['Customer Id'].count()
# Out:
# Productivity
# 24     1
# 46     1
# 47     1
# 48     1
# 54     1
# 61     1
# 70     1
# 74     2
# 76     2
# 77     1
# 78     1
# 94     1
# 101    1
# 120    1
# 130    1
# 168    1
# Name: Customer Id, dtype: int64

# %%
train.groupby('Productivity')['Customer Id'].mean() # mean value
# Out:
# Productivity
# 24      3.0
# 46      4.0
# 47      6.0
# 48      1.0
# 54      5.0
# 61      7.0
# 70     17.0
# 74      9.5
# 76     15.5
# 77      2.0
# 78     12.0
# 94     11.0
# 101    15.0
# 120     8.0
# 130    14.0
# 168    16.0
# Name: Customer Id, dtype: float64
