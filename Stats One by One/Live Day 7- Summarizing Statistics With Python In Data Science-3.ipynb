# %% [markdown]
# ![20.PNG](attachment:20.PNG)

# %% [markdown]
# ![21.PNG](attachment:21.PNG)

# %% [markdown]
# Log normal distribution and parito law distribution is related each other and we can convert it to
# normal distribution with the help of data transformation

# %% [markdown]
# ![23.PNG](attachment:23.PNG)

# %% [markdown]
# ![24.PNG](attachment:24.PNG)

# %% [markdown]
# ![25.PNG](attachment:25.PNG)

# %%
# more bigger value is more better

# %% [markdown]
# ![26.PNG](attachment:26.PNG)

# %%
# Assignment - Poison distribution
