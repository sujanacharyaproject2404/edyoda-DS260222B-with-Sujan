# %% [markdown]
# ### Day30

# %% [markdown]
# ### Permutation And Combination Easily Explained

# %% [markdown]
# ![1.PNG](attachment:1.PNG)

# %% [markdown]
# ![2.PNG](attachment:2.PNG)

# %% [markdown]
# ![3.PNG](attachment:3.PNG)

# %% [markdown]
# ![4.PNG](attachment:4.PNG)

# %% [markdown]
# ### Day31

# %% [markdown]
# ### Why Sample Variance is Divided by n-1

# %% [markdown]
# ![5.PNG](attachment:5.PNG)

# %% [markdown]
# ![6.PNG](attachment:6.PNG)

# %%
# variance get reduced with the help of n-1
# sometimes skewed data will pick some of sample data which is very smaller compare to population mean
