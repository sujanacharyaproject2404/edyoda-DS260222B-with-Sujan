# %%
What is Flask?.
Ans: It is web application framework written in python
    
End to End Project

# %% [markdown]
# ## Setting VSCode IDE To Learn Flask Web Framework For Machine Learning

# %% [markdown]
# create environment : conda create -n 'environment name'(ex: myenv)

# %% [markdown]
# ![anaconda1.PNG](attachment:anaconda1.PNG)

# %%
from flask import Flask
app=Flask(__name__)

@app.route('/')
def welcome():
    return 'Welcome to India'


if __name__=='__main__':
    app.run()

# %% [markdown]
# ## Understanding A Sample Flask Web Application Skeleton

# %% [markdown]
# Required library will be mentioned in requirement.txt file

# %%
To install library : pip install -r requirements.txt or pip install -r .\requirements.txt

# %%
from flask import Flask
app=Flask(__name__)

## WSGI Application
# it is used to communication between web server and web application

@app.route('/')
def welcome():
    return "Welcome to India. Please collect your visa for your safety"

@app.route('/member')
def member():
    return "Welcome to youtube channel, it's for my members"


if __name__=='__main__': 
    app.run(debug=True)

# %% [markdown]
# ## Building Url Dynamically In Flask Web Framework

# %%
### Building Url Dynamically 
####Variable Rules And URL Building

from flask import Flask,redirect,url_for
import pandas
app=Flask(__name__)

@app.route('/')
def welcome():
    return 'Welcome to my Youtube Channel, welcome to india'

@app.route('/success/<int:score>')
def success(score):
    return "<html><body><h1>The Reult is passed</h1></body></html>"


@app.route('/fail/<int:score>')
def fail(score):
    return "The Person has failed and the marks is "+ str(score)

### Result checker
@app.route('/results/<int:marks>')
def results(marks):
    result=""
    if marks<50:
        result='fail'
    else:
        result='success'
    return redirect(url_for(result,score=marks))


if __name__=='__main__':
    app.run(debug=True)

# %% [markdown]
# ## Integrating HTML With FLASK Web Framework With HTTP VERBS(Get And POST)
