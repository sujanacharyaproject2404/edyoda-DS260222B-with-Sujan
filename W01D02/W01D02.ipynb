# %%
print("Hello India!!")    #--> coding mode
# Out:
# Hello India!!

# %% [markdown]
# # Heading
# # H1
# ## H2
# ### H3
# #### H4

# %% [markdown]
# ## BOld
# **SUJAN**    --> for bold use **

# %% [markdown]
#    ###  Italic
#     *Italic features of markdown*   --> for italic use *

# %% [markdown]
# ## Blockquote
# > Hey i'm blockquote   --> for blockquote use >

# %% [markdown]
#  ## Hey i'm heading 2
#  Hey i am bold with # bold, Hey i'm **bold** with    **

# %% [markdown]
# # Odered list
#
# 1. First
# 2. Second
# 3. Third

# %% [markdown]
# ## Unodered list
#
# - First Item
# - Second Item
# - Third Item

# %% [markdown]
# ## Code
# `code mode on`   -->    ` is use to higlight the text or code

# %% [markdown]
# ## Horizontal Rule
#
# ---

# %% [markdown]
# ## Link
# [google](https://www.google.com)

# %% [markdown]
# ## Image
# ![alt.text](image.jpg)

# %% [markdown]
# ### Image
# ![image.png](attachment:image.png)

# %% [markdown]
# | Syntax | Despcription |
# | ------ | ------------ |
# | Header | Title |
# | Paragrapg | Text |

# %% [markdown]
# [Markdown Cheat Sheet](https://www.markdownguide.org/cheat-sheet/)
