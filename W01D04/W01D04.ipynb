# %%
s= "125"   
print(int(s))
# Out:
# 125

# %% [markdown]
# ##### if numbers are inside the string it can be converted into integer format

# %%
st = "125a"
print(int(st))        # if the string has numbers including text then it can't be converted to integer format
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [2], in <cell line: 2>()
#       1 st = "125a"
# ----> 2 print(int(st))
#
# ValueError: invalid literal for int() with base 10: '125a'

# %%
a = int("12.5")      # if the string value is a decimal number then it can't directly be converted to integer
print(a)

a= float("12.5")    # if the string value is a decimal number then it can be converted to float 
print(a)

a= float("12")      # if the string value has a number then it can be converted to float
print(a)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [7], in <cell line: 1>()
# ----> 1 a = int("12.5")      # if the string value is a decimal number then it can't directly be converted to integer
#       2 print(a)
#       4 a= float("12.5")    # if the string value is a decimal number then it can be converted to float
#
# ValueError: invalid literal for int() with base 10: '12.5'

# %%
a = int("12.5")     
print(a)

a= float("12.5")  
print(a)

a= float("12")      
print(a)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [12], in <cell line: 1>()
# ----> 1 a = int("12.5")
#       2 print(a)
#       4 a= float("12.5")
#
# ValueError: invalid literal for int() with base 10: '12.5'

# %%
a=(1,2,3)

# %%
# [] is used for making list
# list is not be a key, because it's changeable.
l = [1,2.1,"sujan",None,True, 2+3j]
print(l[2][1])                      
# if multiple values inside the list ,if we want to access any one of the values then we can get the result if we put []
# or if we want to access the any one of the digits inside the value then we  have to put [][ ] 
# example: 
#           a= [1,"sujan"]
#           print (a[1][1]) 
# output:u
# Out:
# u

# %%
d = {"Jan": "January"}
print(d["Jan"])
# Out:
# January

# %%
 l= [1,"USA",3.0]        # if we give any of the index is equal to any value then it would be consider the updated value.
l[1] = "India"
print(l[1])
# Out:
# India

# %%
#Dictionary:
# it's mutable data type.
# Key of the dictionary is immutable.
# it's non indexibel.
d = {"Jan": "January"}
print(d["Jan"])
Dictionary are a case sensitive
If we miss any one of the character then we will get error.
all Mutable things can be a key.
# Out:
#   Input In [9]
#     Dictionary are a case sensitive
#                ^
# SyntaxError: invalid syntax

# %%
a=(1,2,3)
b=(1,2,3)
print(id(a[0])==id(b[0]))
# Out:
# True
# 2

# %%
# l=[1,2,5,8,"sharon"]   in list we have 5 objects, we should consider list as an object.
# s={1,("sujan",5),4}    in set and tuple we have 6 objects, we should consider tuple and set as an objects.

# %% [markdown]
# ### In this example list  has 5 objects
# ![List Objects](attachment:image.png)

# %% [markdown]
# ## In this example sets and tuples  has 6 objects
# ![sets and tuples objects](attachment:image.png)
