# %% [markdown]
# ### Multiple Linear Regression

# %% [markdown]
# ![multiple_linear_regression.PNG](attachment:multiple_linear_regression.PNG)

# %% [markdown]
# ![multiple_linear_regression1.PNG](attachment:multiple_linear_regression1.PNG)
