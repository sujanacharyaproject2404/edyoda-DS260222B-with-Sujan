# %% [markdown]
# 1. Bias & Variance
# 2. Regularisation
# 3. Bias Variance Trade off
# 4. Lasso Regression

# %% [markdown]
# #### supervised machine learning
#
# `Linear Regression (y=mx+c)  #(it's comming under supervised machine learning)`
#
# `Multiple Linear Regession ( y = (m1x1)*(m2x2)*(m3x3) + c)`

# %% [markdown]
# Regression Means - Target should be continues

# %% [markdown]
# Multiple Linear Regression - has one dependent variable and multiple independent variable.

# %%
#because of less data we didn't do test train

# %%
import pandas as pd
import numpy as np
df = pd.read_csv(r"D:\Data Science\MACHINE LEARNING\Salary_Data.csv")
df.head()
# Out:
#    YearsExperience   Salary
# 0              1.1  39343.0
# 1              1.3  46205.0
# 2              1.5  37731.0
# 3              2.0  43525.0
# 4              2.2  39891.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 2 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   YearsExperience  30 non-null     float64
#  1   Salary           30 non-null     float64
# dtypes: float64(2)
# memory usage: 608.0 bytes

# %%
df.describe()
# Out:
#        YearsExperience         Salary
# count        30.000000      30.000000
# mean          5.313333   76003.000000
# std           2.837888   27414.429785
# min           1.100000   37731.000000
# 25%           3.200000   56720.750000
# 50%           4.700000   65237.000000
# 75%           7.700000  100544.750000
# max          10.500000  122391.000000

# %%
df.isnull().sum()
# Out:
# YearsExperience    0
# Salary             0
# dtype: int64

# %%
df.corr()
# Out:
#                  YearsExperience    Salary
# YearsExperience         1.000000  0.978242
# Salary                  0.978242  1.000000

# %%
import matplotlib.pyplot as plt
plt.scatter(df.YearsExperience, df.Salary)
plt.xlabel('experience')
plt.ylabel('Salary')
plt.show()

# %%
df.head()
# Out:
#    YearsExperience   Salary
# 0              1.1  39343.0
# 1              1.3  46205.0
# 2              1.5  37731.0
# 3              2.0  43525.0
# 4              2.2  39891.0

# %%
a = df.loc[:, ['YearsExperience', 'Salary']]
a.plot()
# Out:
# <AxesSubplot:>

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
x = df.YearsExperience.values.reshape(-1,1)
y = df.Salary.values.reshape(-1,1)

# %%
lr.fit(x,y)
# Out:
# LinearRegression()

# %%
x
# Out:
# array([[ 1.1],
#        [ 1.3],
#        [ 1.5],
#        [ 2. ],
#        [ 2.2],
#        [ 2.9],
#        [ 3. ],
#        [ 3.2],
#        [ 3.2],
#        [ 3.7],
#        [ 3.9],
#        [ 4. ],
#        [ 4. ],
#        [ 4.1],
#        [ 4.5],
#        [ 4.9],
#        [ 5.1],
#        [ 5.3],
#        [ 5.9],
#        [ 6. ],
#        [ 6.8],
#        [ 7.1],
#        [ 7.9],
#        [ 8.2],
#        [ 8.7],
#        [ 9. ],
#        [ 9.5],
#        [ 9.6],
#        [10.3],
#        [10.5]])

# %%
lr.predict([[25.8]])
# Out:
# array([[269601.22809221]])

# %%
df1 = pd.read_csv(r"D:\Data Science\MACHINE LEARNING\Advertising.csv")
df1.head()
# Out:
#    Unnamed: 0     TV  Radio  Newspaper  Sales
# 0           1  230.1   37.8       69.2   22.1
# 1           2   44.5   39.3       45.1   10.4
# 2           3   17.2   45.9       69.3    9.3
# 3           4  151.5   41.3       58.5   18.5
# 4           5  180.8   10.8       58.4   12.9

# %%
df1.shape
# Out:
# (200, 5)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  200 non-null    int64
#  1   TV          200 non-null    float64
#  2   Radio       200 non-null    float64
#  3   Newspaper   200 non-null    float64
#  4   Sales       200 non-null    float64
# dtypes: float64(4), int64(1)
# memory usage: 7.9 KB

# %%
df1.describe()
# Out:
#        Unnamed: 0          TV       Radio   Newspaper       Sales
# count  200.000000  200.000000  200.000000  200.000000  200.000000
# mean   100.500000  147.042500   23.264000   30.554000   14.022500
# std     57.879185   85.854236   14.846809   21.778621    5.217457
# min      1.000000    0.700000    0.000000    0.300000    1.600000
# 25%     50.750000   74.375000    9.975000   12.750000   10.375000
# 50%    100.500000  149.750000   22.900000   25.750000   12.900000
# 75%    150.250000  218.825000   36.525000   45.100000   17.400000
# max    200.000000  296.400000   49.600000  114.000000   27.000000

# %%
df1.isnull().sum()
# Out:
# Unnamed: 0    0
# TV            0
# Radio         0
# Newspaper     0
# Sales         0
# dtype: int64

# %%
import seaborn as sns
fig, axs = plt.subplots(3, figsize = (6,5))
sns.boxplot(df1['TV'], ax = axs[0])
sns.boxplot(df1['Newspaper'],  ax = axs[1])
sns.boxplot(df1['Radio'],  ax = axs[2])
# Out:
# D:\Data Science\python 3.10\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# D:\Data Science\python 3.10\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# D:\Data Science\python 3.10\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ...

# %%
sns.pairplot(df1, x_vars = ['TV', 'Newspaper', 'Radio'])

# %%
sns.heatmap(df1.corr(), annot = True)
plt.show()

# %%
X = df1['TV']
y = df1['Sales']

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y ,test_size = 0.3, random_state = 0)

# %%
import statsmodels.api as sm

# %%
X_train_sm = sm.add_constant(X_train) # sm.add_constant(X_train) is help us to add constant- constant basically means intersept value
lr = sm.OLS(y_train, X_train_sm).fit() # OLS-Ordinary list squared model

#lr - Linear Regression
# Ols required before training  a machine learning model it require to intercept before.
X = sm.add_constant(X)  # it is for get output for summary

# %%
lr.params
# Out:
# const    7.310810
# TV       0.045814
# dtype: float64

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
x = df.YearsExperience.values.reshape(-1,1)
y = df.Salary.values.reshape(-1,1)

# %%
print(lr.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  Sales   R-squared:                       0.555
# Model:                            OLS   Adj. R-squared:                  0.552
# Method:                 Least Squares   F-statistic:                     172.3
# Date:                Wed, 20 Jul 2022   Prob (F-statistic):           4.76e-26
# Time:                        03:29:12   Log-Likelihood:                -371.64
# No. Observations:                 140   AIC:                             747.3
# Df Residuals:                     138   BIC:                             753.2
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          7.3108      0.611     11.957      0.000       6.102       8.520
# ...

# %%
df1.head()

# %%
plt.scatter(X_train, y_train)
plt.plot(X_train, 6.879 + 0.064*X_train, 'r')
plt.show()

# %%
df2 = pd.read_csv(r"D:\Data Science\MACHINE LEARNING\insurance.csv")
df2.head()

# %%
sns.lmplot(x='bmi', y='expenses', data=df2)

# %%
sns.lmplot(x='bmi', y='expenses', data=df2, aspect=2, height=7) # aspect=2 means it will multiple the height with aspect value
                                                                # ex: aspect(2)*height(7)=14 is width.

# %% [markdown]
# `Linear Regression is a model which helps us to make best fit line through out your data point.`
#
# `Linear Regression is coming under supervise machine learning model.`

# %%
df2.info()

# %%
df2.describe()

# %%
corr = df2.corr()
sns.heatmap(corr, annot = True, cmap = 'Wistia')

# %%
df2.head()

# %%
cat_col = ['sex', 'children', 'smoker', 'region']
df_encode = pd.get_dummies(data = df2)  # encoding

# %%
df_encode

# %% [markdown]
# ### Linear Regression

# %% [markdown]
# `We should do standardization only for training(x_train) and not for output(testing(x_test))`

# %% [markdown]
# standardization formula z=(x-u)/s

# %% [markdown]
# ![standardscaler.PNG](attachment:standardscaler.PNG)

# %%
# ridge or lasso is to do hyperpyrometer

# %% [markdown]
# ![problem1.PNG](attachment:problem1.PNG)

# %% [markdown]
# `fit - will compute mean and standard deviation`

# %% [markdown]
# `transform - we will apply entire standard deviation formula`

# %% [markdown]
# fit - training data \
# predict - test or new data

# %% [markdown]
# fit and transform - training data\
# transform - test data
#
# This will actually helps us to overcome, overfitting
